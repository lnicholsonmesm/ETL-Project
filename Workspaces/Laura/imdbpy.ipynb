# %%
import imdb
from pprint import pprint

# %% [markdown]
# ## Key Functions
# - search
# - get
#
#
# .items()
# .search()
# .get()
# runtimes
#
# .get_movie() <- id param
# get_movie_infoset()
# .get_company_infoset()
# .getID()
# .get_keyword()
# .get_top250_movies()
# .get_top250_indian_movies()
# .get_top250_tv()
# .get_popular100_movies()
# .get_bottom100_movies()
#
# if you do a movie search operation, the movie objects in the result won’t have many of the keys that would be available on a movie get operation
# search_person()
# search_company()
# .search_movie()
# .search_keyword()
#
# ## Parameters
# info='keywords'
#
# ## objects
# >>> movies[0]['title']
# 'The Matrix'
# >>> people[0]['name']
# 'Angelina Jolie'
# >>> companies[0]['name']
# 'RKO'
#
# Titles
# The analyze_title() and build_title() functions now support TV episodes. You can pass a string to the analyze_title function in the format used by the web server ("The Series" The Episode (2005)) or in the format of the plain text data files ("The Series" (2004) {The Episode (#ser.epi)}).
#
#
#
# The episode of key can be a dictionary or a Movie instance with the same information.
#
# The build_title() function takes an optional argument: ptdf, which when set to false (the default) returns the title of the episode in the format used by the IMDb’s web server (“The Series” An Episode (2006)); otherwise, it uses the format used by the plain text data files (something like “The Series” (2004) {An Episode (#2.5)})
#
#
# ## attributes
# .default_info
# .current_info
# .infoset2keys
#
# ## methods
# update()
# You can find some examples of these functions in the imdb.utils module.
#
# The function used to modify the strings can be set with the defaultModFunct parameter of the IMDb class or with the modFunct parameter of the get_movie, get_person, and get_character methods:
#
# ## catch errors
# from imdb import IMDb, IMDbError
#
# try:
#     ia = IMDb()
#     people = ia.search_person('Mel Gibson')
# except IMDbError as e:
#     print(e)
#
#     ## The get_movie, get_person and get_company methods take an optional info parameter, which can be used to specify the kinds of data to fetch.
#
#     In some data, the (not-so) universal :: separator is used to delimit parts of the data inside a string, like the plot of a movie and its author:
#
#     As a rule, there’s at most one such separator inside a string. Splitting the string will result in two logical pieces as in TEXT::NOTE. The imdb.helpers.makeTextNotes() function can be used to create a custom function to pretty-print this kind of information.
#
# ## operators
#     in operator
#
#   ## keys
#     kind <- for series
#
# ## ratings
# You can retrieve rating information about every episode in a TV series or mini series using the ‘episodes rating’ data set.
#
#
# In the imdb.helpers module there’s the parseXML() function which takes a string as input and returns -if possible- an instance of the Movie, Person, Character or Company class.
#
# ## akas
# akasLanguages(movie) - Given a movie, return a list of tuples in (lang, AKA) format (lang can be None, if unable to detect).
# sortAKAsBySimilarity(movie, title) - Sort the AKAs on a movie considering how much they are similar to a given title (see the code for more options).
# getAKAsInLanguage(movie, lang) - Return a list of AKAs of the movie in the given language (see the code for more options).

# %% [markdown]
# ## Key Examples
# deadpool_movies_2018 = [ m for m in deadpool_matches if m['year'] == '2018' ]
# i = imdb.IMDb(defaultModFunct=imdb.utils.modHtmlLinks)
# myPrint = imdb.helpers.makeObject2Txt(personTxt='<if personID><a href=/person/%(personID)s></if personID>%(long imdb name)s<if personID></a></if personID><if currentRole> ... %(currentRole)s<if notes> %(notes)s</if notes></if currentRole>'

# %% [markdown]
# ## Movie Object Attributes
# movie.default_info
# movie.current_info

# %% [markdown]
# ## cast
# currentRole
# notes

# %%
ia = imdb.IMDb()

# %%
# Searching

#movies = ia.search_movie('title')
#people = ia.search_person('angelina')
#

# %%
actor_results = ia.get_person_filmography('0001098')

# %%
pprint(actor_results)
# Out:
# {'data': {'akas': ['Jack Roy'],
#           'birth info': {'birth place': 'Deer Park, Long Island, New York, '
#                                         'USA'},
#           'death info': {'death place': 'Los Angeles, California, USA'},
#           'filmography': {'actor': [<Movie id:0392878[http] title:_The Onion Movie (2008)_>,
#                                     <Movie id:0179803[http] title:_Angels with Angles (2005)_>,
#                                     <Movie id:0320970[http] title:_"Still Standing" (2004)_>,
#                                     <Movie id:0313245[http] title:_Back by Midnight (2004)_>,
#                                     <Movie id:0340281[http] title:_"Phil of the Future" (2004)_>,
#                                     <Movie id:0377056[http] title:_The Electric Piper (2003) (TV)_>,
#                                     <Movie id:0275170[http] title:_The 4th Tenor (2002)_>,
#                                     <Movie id:0185431[http] title:_Little Nicky (2000)_>,
#                                     <Movie id:0216930[http] title:_My 5 Wives (2000)_>,
#                                     <Movie id:0198911[http] title:_Pirates: 3D Show (1999)_>,
#                                     <Movie id:0120044[http] title:_Rusty: A Dog's Tale (1998)_>,
#                                     <Movie id:0165303[http] title:_The Godson (1998)_>,
#                                     <Movie id:0158459[http] title:_Sea World and Busch Gardens Adventures: Alien Vacation! (1997)_>,
#                                     <Movie id:0101120[http] title:_"Home Improvement" (1997)_>,
#                                     <Movie id:0118824[http] title:_Casper: A Spirited Beginning (1997)_>,
#                                     <Movie id:0119644[http] title:_Meet Wally Sparks (1997)_>,
#                                     <Movie id:0111942[http] title:_"Dr. Katz, Professional Therapist" (1997)_>,
#                                     <Movie id:0115376[http] title:_"Suddenly Susan" (1996)_>,
#                                     <Movie id:0096697[http] title:_"The Simpsons" (1996)_>,
#                                     <Movie id:0112163[http] title:_"The Single Guy" (1996)_>,
#                                     <Movie id:0112642[http] title:_Casper (1995)_>,
#                                     <Movie id:0248053[http] title:_Guide to Golf Style and Etiquette (1995)_>,
#                                     <Movie id:0110632[http] title:_Natural Born Killers (1994)_>,
#                                     <Movie id:0460514[http] title:_Muscle Rock Madness (1992)_>,
#                                     <Movie id:0104670[http] title:_Ladybugs (1992)_>,
#                                     <Movie id:0102813[http] title:_Rover Dangerfield (1991)_>,
#                                     <Movie id:0255132[http] title:_The Earth Day Special (1990)_>,
#                                     <Movie id:10918932[http] title:_Sam Kinison: Wild Thing (1988)_>,
#                                     <Movie id:0095662[http] title:_Moving (1988)_>,
#                                     <Movie id:6889212[http] title:_Rodney Dangerfield: Twist and Shout (1986)_>,
#                                     <Movie id:7126632[http] title:_Lionel Richie: Dancing on the Ceiling (1986)_>,
#                                     <Movie id:0090685[http] title:_Back to School (1986)_>,
#                                     <Movie id:11921096[http] title:_Miller Lite: Tastes Great, Less Filling (1977-1986) (None)_>,
#                                     <Movie id:0085065[http] title:_"Not Necessarily the News" (1985)_>,
#                                     <Movie id:8460750[http] title:_Rodney Dangerfield: Rappin' Rodney (1984)_>,
#                                     <Movie id:0085470[http] title:_Easy Money (1983)_>,
#                                     <Movie id:0080487[http] title:_Caddyshack (1980)_>,
#                                     <Movie id:0075741[http] title:_Benny and Barney: Las Vegas Undercover (1977) (TV)_>,
#                                     <Movie id:0067622[http] title:_The Projectionist (1970)_>,
#                                     <Movie id:1415092[http] title:_"NBC Experiment in Television" (1969)_>,
#                                     <Movie id:0062606[http] title:_"That's Life (1968-1969)" (None)_>,
#                                     <Movie id:0049406[http] title:_The Killing (1956)_>],
#                           'archive footage': [<Movie id:10290552[http] title:_"The Very Very Best of the 70s" (2019)_>,
#                                               <Movie id:5737466[http] title:_The History of Comedy (2017)_>,
#                                               <Movie id:1653313[http] title:_"Board James" (2015)_>,
#                                               <Movie id:2345915[http] title:_Beer and Board Games (2014)_>,
#                                               <Movie id:0284767[http] title:_"The O'Reilly Factor" (2014)_>,
#                                               <Movie id:3268200[http] title:_The Sixties (2014)_>,
#                                               <Movie id:3993252[http] title:_"Video Games AWESOME!" (2014)_>,
#                                               <Movie id:3591608[http] title:_The Improv: 50 Years Behind the Brick Wall (2013)_>,
#                                               <Movie id:2378587[http] title:_When Jews Were Funny (2013)_>,
#                                               <Movie id:2167056[http] title:_When Comedy Went to School (2013)_>,
#                                               <Movie id:0092322[http] title:_Biography (2000-2012) (None)_>,
#                                               <Movie id:1636741[http] title:_Caddyshack: The Inside Story (2009)_>,
#                                               <Movie id:0103569[http] title:_"The Tonight Show with Jay Leno" (2009)_>,
#                                               <Movie id:1520788[http] title:_The Greatest (2009)_>,
#                                               <Movie id:1687250[http] title:_Mike Douglas: Moments & Memories (2008)_>,
#                                               <Movie id:0865327[http] title:_Legends: Rodney Dangerfield (2006)_>,
#                                               <Movie id:0475057[http] title:_The 57th Annual Primetime Emmy Awards (2005)_>,
#                                               <Movie id:0429487[http] title:_The 77th Annual Academy Awards (2005)_>,
#                                               <Movie id:0445913[http] title:_11th Annual Screen Actors Guild Awards (2005)_>,
#                                               <Movie id:0429332[http] title:_100 Greatest Stand-Ups of All Time (2004)_>,
#                                               <Movie id:0362253[http] title:_Tragedy to Triumph: The Maryland Terrapin Odyssey (2003)_>,
#                                               <Movie id:0282856[http] title:_Porn Star: The Legend of Ron Jeremy (2001)_>,
#                                               <Movie id:0354351[http] title:_Caddyshack: The 19th Hole (1999)_>,
#                                               <Movie id:0326053[http] title:_A Really Big Show: Ed Sullivan's 50th Anniversary (1998)_>,
#                                               <Movie id:0251104[http] title:_The Great Standups (1984)_>,
#                                               <Movie id:6086298[http] title:_Texaco Star Theatre Presents Bob Hope in 'Who Makes the World Laugh?' (1983)_>,
#                                               <Movie id:1305556[http] title:_The Tonight Show Starring Johnny Carson 19th Anniversary Special (1981)_>,
#                                               <Movie id:1071303[http] title:_Johnny Carson's 18th Anniversary Special (1980)_>],
#                           'composer': [<Movie id:8460750[http] title:_Rodney Dangerfield: Rappin' Rodney (1984)_>],
#                           'music department': [<Movie id:0102813[http] title:_Rover Dangerfield (1991)_>,
#                                                <Movie id:8460750[http] title:_Rodney Dangerfield: Rappin' Rodney (1984)_>],
#                           'producer': [<Movie id:1032238[http] title:_Rodney's Act (2004)_>,
#                                        <Movie id:0216930[http] title:_My 5 Wives (2000)_>,
#                                        <Movie id:0253596[http] title:_Rodney Dangerfield's 75th Birthday Toast (1997)_>,
#                                        <Movie id:0119644[http] title:_Meet Wally Sparks (1997)_>,
#                                        <Movie id:0248916[http] title:_It's Lonely at the Top (1992) (TV)_>,
#                                        <Movie id:0102813[http] title:_Rover Dangerfield (1991)_>],
#                           'script and continuity department': [<Movie id:0094824[http] title:_Caddyshack II (1988)_>],
#                           'self': [<Movie id:1032238[http] title:_Rodney's Act (2004)_>,
#                                    <Movie id:0320037[http] title:_"Jimmy Kimmel Live!" (2004)_>,
#                                    <Movie id:0284767[http] title:_"The O'Reilly Factor" (2004)_>,
#                                    <Movie id:0192906[http] title:_"The Late Late Show with Craig Kilborn" (2004)_>,
#                                    <Movie id:0103569[http] title:_"The Tonight Show with Jay Leno (1995-2004)" (None)_>,
#                                    <Movie id:0393166[http] title:_The Commies (2003)_>,
#                                    <Movie id:0476288[http] title:_The Lionel Richie Collection (2003)_>,
#                                    <Movie id:0081857[http] title:_"Entertainment Tonight" (2003)_>,
#                                    <Movie id:0138968[http] title:_"Hollywood Squares" (2002)_>,
#                                    <Movie id:0305176[http] title:_Adam Sandler Goes to Hell (2001)_>,
#                                    <Movie id:0364995[http] title:_Billy Joel: The Essential Video Collection (2001)_>,
#                                    <Movie id:0426824[http] title:_"XFL Football League" (2001)_>,
#                                    <Movie id:5819408[http] title:_"Laugh Factory" (1999)_>,
#                                    <Movie id:0112056[http] title:_"MADtv (1997-1999)" (None)_>,
#                                    <Movie id:0174180[http] title:_Sam Kinison: Why Did We Laugh? (1999)_>,
#                                    <Movie id:0162110[http] title:_"Sin City Spectacular" (1998)_>,
#                                    <Movie id:0112097[http] title:_"Night Stand" (1997)_>,
#                                    <Movie id:0253596[http] title:_Rodney Dangerfield's 75th Birthday Toast (1997)_>,
#                                    <Movie id:0159879[http] title:_"Howard Stern" (1997)_>,
#                                    <Movie id:0106052[http] title:_"Late Night with Conan O'Brien" (1997)_>,
#                                    <Movie id:0115147[http] title:_"The Daily Show" (1997)_>,
#                                    <Movie id:0224855[http] title:_"Crook & Chase" (1996)_>,
#                                    <Movie id:0072562[http] title:_"Saturday Night Live (1979-1996)" (None)_>,
#                                    <Movie id:1044985[http] title:_The 10th Annual American Comedy Awards (1996)_>,
#                                    <Movie id:0112707[http] title:_A Comedy Salute to Andy Kaufman (1995)_>,
#                                    <Movie id:0324325[http] title:_A Tribute to Sam Kinison (1993)_>,
#                                    <Movie id:0098830[http] title:_"In Living Color" (1993)_>,
#                                    <Movie id:0248916[http] title:_It's Lonely at the Top (1992) (TV)_>,
#                                    <Movie id:0055708[http] title:_"The Tonight Show Starring Johnny Carson (1969-1992)" (None)_>,
#                                    <Movie id:0427790[http] title:_Rodney Dangerfield's The Really Big Show (1991)_>,
#                                    <Movie id:0224983[http] title:_...Where's Rodney? (1990) (TV)_>,
#                                    <Movie id:3322478[http] title:_An Amazin Era: Revised and Updated (1989)_>,
#                                    <Movie id:0453392[http] title:_Rodney Dangerfield: Opening Night at Rodney's Place (1989)_>,
#                                    <Movie id:0148538[http] title:_Nothin' Goes Right (1988)_>,
#                                    <Movie id:0790783[http] title:_Will Rogers: Look Back in Laughter (1987) (TV)_>,
#                                    <Movie id:0331410[http] title:_The 59th Annual Academy Awards (1987)_>,
#                                    <Movie id:0375546[http] title:_An Amazin' Era (1986)_>,
#                                    <Movie id:0334249[http] title:_Rodney Dangerfield: It's Not Easy Bein' Me (1986)_>,
#                                    <Movie id:0083441[http] title:_"Late Night with David Letterman" (1986)_>,
#                                    <Movie id:0451141[http] title:_The 9th Annual Young Comedians Special (1985)_>,
#                                    <Movie id:6435566[http] title:_Playboy Mid Summer Night's Dream Party 1985 (1985) (TV)_>,
#                                    <Movie id:0426564[http] title:_Rodney Dangerfield: Exposed (1985)_>,
#                                    <Movie id:0804435[http] title:_The 26th Annual Grammy Awards (1984)_>,
#                                    <Movie id:1669700[http] title:_The Top (1984) (TV)_>,
#                                    <Movie id:7720928[http] title:_Billy Joel: Tell Her About It (1983)_>,
#                                    <Movie id:0828112[http] title:_The Rodney Dangerfield Special: I Can't Take It No More (1983)_>,
#                                    <Movie id:0267709[http] title:_The Making of 'Easy Money' (1983)_>,
#                                    <Movie id:0355589[http] title:_The Rodney Dangerfield Show: It's Not Easy Bein' Me (1982)_>,
#                                    <Movie id:0344272[http] title:_The Robert Klein Show (1981)_>,
#                                    <Movie id:0343544[http] title:_Command Performance: The Stars Salute the President (1981)_>,
#                                    <Movie id:1032263[http] title:_This Is Your Life: 30th Anniversary Special (1981)_>,
#                                    <Movie id:0343331[http] title:_The 23rd Annual Grammy Awards (1981)_>,
#                                    <Movie id:0179553[http] title:_"The Alan Thicke Show (1980-1981)" (None)_>,
#                                    <Movie id:0158435[http] title:_"Tomorrow Coast to Coast" (1980)_>,
#                                    <Movie id:0138960[http] title:_"Live Wednesday" (1978)_>,
#                                    <Movie id:0059995[http] title:_"The Hollywood Squares (1976-1978)" (None)_>,
#                                    <Movie id:0335141[http] title:_Happy Birthday, Las Vegas (1977)_>,
#                                    <Movie id:0287229[http] title:_"I've Got a Secret" (1976)_>,
#                                    <Movie id:0198081[http] title:_"Celebrity Sweepstakes" (1976)_>,
#                                    <Movie id:0070979[http] title:_"The Dean Martin Comedy World" (1974)_>,
#                                    <Movie id:0170980[http] title:_"The Mike Douglas Show (1968-1973)" (None)_>,
#                                    <Movie id:0058797[http] title:_"The Dean Martin Show" (1972)_>,
#                                    <Movie id:0055691[http] title:_"The Merv Griffin Show (1965-1972)" (None)_>,
#                                    <Movie id:0063890[http] title:_"The David Frost Show (1969-1971)" (None)_>,
#                                    <Movie id:0040053[http] title:_"The Ed Sullivan Show (1967-1971)" (None)_>,
#                                    <Movie id:0065283[http] title:_"Comedy Tonight" (1970)_>,
#                                    <Movie id:0195466[http] title:_"The Jackie Gleason Show" (1970)_>,
#                                    <Movie id:0063892[http] title:_"Della" (1969)_>,
#                                    <Movie id:0124948[http] title:_"The Joan Rivers Show (1968-1969)" (None)_>,
#                                    <Movie id:0061268[http] title:_"The Joey Bishop Show (1967-1969)" (None)_>,
#                                    <Movie id:0062606[http] title:_"That's Life" (1969)_>,
#                                    <Movie id:0300833[http] title:_"Operation: Entertainment" (1968)_>,
#                                    <Movie id:1277990[http] title:_"The Steve Allen Show" (1968)_>,
#                                    <Movie id:0260612[http] title:_"The Eamonn Andrews Show" (1967)_>,
#                                    <Movie id:0061235[http] title:_"Away We Go" (1967)_>,
#                                    <Movie id:0057777[http] title:_"On Broadway Tonight" (1964)_>],
#                           'soundtrack': [<Movie id:4560190[http] title:_One Hit Wonderland () (None)_>,
#                                          <Movie id:0488915[http] title:_I Love the 80's 3-D (2005)_>,
#                                          <Movie id:0119644[http] title:_Meet Wally Sparks (1997)_>,
#                                          <Movie id:0104670[http] title:_Ladybugs (1992)_>,
#                                          <Movie id:0427790[http] title:_Rodney Dangerfield's The Really Big Show (1991)_>,
#                                          <Movie id:0102813[http] title:_Rover Dangerfield (1991)_>,
#                                          <Movie id:0090685[http] title:_Back to School (1986)_>,
#                                          <Movie id:0426564[http] title:_Rodney Dangerfield: Exposed (1985)_>,
#                                          <Movie id:0828112[http] title:_The Rodney Dangerfield Special: I Can't Take It No More (1983)_>,
#                                          <Movie id:0085470[http] title:_Easy Money (1983)_>,
#                                          <Movie id:0355589[http] title:_The Rodney Dangerfield Show: It's Not Easy Bein' Me (1982)_>],
#                           'thanks': [<Movie id:4910938[http] title:_Surely, You Jest (2019)_>,
#                                      <Movie id:1872847[http] title:_Stupa-Man (2008)_>,
#                                      <Movie id:0437048[http] title:_1989 Johnnie Walker National Comedy Search (1989) (TV)_>,
#                                      <Movie id:0168459[http] title:_The Diceman Cometh (1989)_>],
#                           'writer': [<Movie id:1032238[http] title:_Rodney's Act (2004)_>,
#                                      <Movie id:0313245[http] title:_Back by Midnight (2004)_>,
#                                      <Movie id:0275170[http] title:_The 4th Tenor (2002)_>,
#                                      <Movie id:0216930[http] title:_My 5 Wives (2000)_>,
#                                      <Movie id:0253596[http] title:_Rodney Dangerfield's 75th Birthday Toast (1997)_>,
#                                      <Movie id:0119644[http] title:_Meet Wally Sparks (1997)_>,
#                                      <Movie id:0111942[http] title:_"Dr. Katz, Professional Therapist" (1997)_>,
#                                      <Movie id:0248053[http] title:_Guide to Golf Style and Etiquette (1995)_>,
#                                      <Movie id:0248916[http] title:_It's Lonely at the Top (1992) (TV)_>,
#                                      <Movie id:0427790[http] title:_Rodney Dangerfield's The Really Big Show (1991)_>,
#                                      <Movie id:0102813[http] title:_Rover Dangerfield (1991)_>,
#                                      <Movie id:0453392[http] title:_Rodney Dangerfield: Opening Night at Rodney's Place (1989)_>,
#                                      <Movie id:0148538[http] title:_Nothin' Goes Right (1988)_>,
#                                      <Movie id:0334249[http] title:_Rodney Dangerfield: It's Not Easy Bein' Me (1986)_>,
#                                      <Movie id:0090685[http] title:_Back to School (1986)_>,
#                                      <Movie id:0426564[http] title:_Rodney Dangerfield: Exposed (1985)_>,
#                                      <Movie id:0828112[http] title:_The Rodney Dangerfield Special: I Can't Take It No More (1983)_>,
#                                      <Movie id:0085470[http] title:_Easy Money (1983)_>,
#                                      <Movie id:0355589[http] title:_The Rodney Dangerfield Show: It's Not Easy Bein' Me (1982)_>]},
#           'headshot': 'https://m.media-amazon.com/images/M/MV5BMTUzMjkxMTY5MF5BMl5BanBnXkFtZTYwODg1NDgz._V1_UX214_CR0,0,214,317_AL_.jpg',
#           'imdbID': '0001098',
#           'name': 'Rodney Dangerfield'},
#  'info sets': ('main', 'filmography'),
#  'namesRefs': {},
#  'titlesRefs': {}}

# %%
actor_results['data']['filmography']['actor'][0].getID()
actor_results['data']['filmography']['actor'][0].getID()
# Out:
# <Movie id:0392878[http] title:_The Onion Movie (2008)_>
