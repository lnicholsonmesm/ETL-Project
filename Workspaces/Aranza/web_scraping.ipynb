# %%
from bs4 import BeautifulSoup
import requests

# %%
url = "https://editorial.rottentomatoes.com/guide/best-black-movies-21st-century/"
response = requests.get(url)
print(response.text)
# Out:
# <!DOCTYPE html>
# <html lang="en-US">
#     <head prefix="og: http://ogp.me/ns# flixstertomatoes: http://ogp.me/ns/apps/flixstertomatoes#">
#     <meta http-equiv="content-type" content="text/html; charset=UTF-8" />
#         <meta property='og.description' content="From Get Out and Selma to Girls Trip and Moonlight, these are the most critically acclaimed Certified Fresh African American movies of the century so far." />
#     <meta name='description' content="From Get Out and Selma to Girls Trip and Moonlight, these are the most critically acclaimed Certified Fresh African American movies of the century so far." />
#     <meta property='og:title' content="The 100 Best Black Movies of the 21st Century - The Greatest New African American Films" />
#     <meta property='og:type' content="article" />
#     <meta property='og:image' content="https://s3-us-west-2.amazonaws.com/flx-editorial-wordpress/wp-content/uploads/2020/01/31154351/Black-Films.jpg" />
#     <meta property='og:url' content="https://editorial.rottentomatoes.com/guide/best-black-movies-21st-century/" />
#     <meta name='editorialID' content="172375"/>
#     <meta property='fb:app_id' content="326803741017"/>
#
#     <meta property='twitter:card' content="summary_large_image" />
#     <meta name="twitter:site" content="@rottentomatoes" />
#     <meta name="twitter:title" content="The 100 Best Black Movies of the 21st Century - The Greatest New African American Films" />
#     <meta name="twitter:description" content="From Get Out and Selma to Girls Trip and Moonlight, these are the most critically acclaimed Certified Fresh African American movies of the century so far." />
#     <meta name="twitter:image" content="https://s3-us-west-2.amazonaws.com/flx-editorial-wordpress/wp-content/uploads/2020/01/31154351/Black-Films.jpg" />
#
#
#                     <link rel="stylesheet" type="text/css" href="https://editorial.rottentomatoes.com/wp-content/themes/RottenTomatoes/css/guide.css" media="screen" />
#
#     <title>  The 100 Best Black Movies of the 21st Century &#8211; The Greatest New African American Films << Rotten Tomatoes &#8211; Movie and TV News</title>
#     <meta http-equiv="X-UA-Compatible" content="IE=edge">
#     <meta name="viewport" content="width=device-width, initial-scale=1">
#     <link rel="pingback" href="https://editorial.rottentomatoes.com/xmlrpc.php" />
#     <!-- Make customizable later -->
#     <link href="https://static.rottentomatoes.com/static/styles/bootstrapLess/rt_bootstrap.css" rel="stylesheet"/>
#     <link href="https://static.rottentomatoes.com/v/less/?f=/styles/rt_redesign.less" rel="stylesheet"/>
#     <link rel="stylesheet" href="https://editorial.rottentomatoes.com/wp-content/themes/RottenTomatoes/css/rtmobilenav.css">
#     <link href="https://static.rottentomatoes.com/v/less/?f=/styles/hub.less" rel="stylesheet"/>
#     <link href="//ajax.googleapis.com/ajax/libs/jqueryui/1.11.3/themes/smoothness/jquery-ui.min.css" rel="stylesheet"/>
#     <link rel="icon" type="image/x-icon" href="https://static.rottentomatoes.com/static/images/icons/favicon.ico">
#     <link rel="stylesheet" href="/wp-content/themes/RottenTomatoes/css/visual-refresh.css">
#
#         <script>
#         // Push column to dataLayer
#         var dataLayer = dataLayer || [];
#
#         dataLayer.push({
#           "post-url": "https:\/\/editorial.rottentomatoes.com\/guide\/best-black-movies-21st-century\/",
#           "column": "18",
#           "hub":"",
#           "author": "rt-staff",
#           "related-tv-series-ids": [],
#           "related-movie-ids": ["10283","10414","10577","11030","11438","126518499","12784","13267","13368","14819","152552156","155655104","15861","17495","1788","2132","358047697","49248977","493864880","770671119","770679318","770682608","770800373","770802637","770803691","770873459","771205918","771228631","771234052","771245718","771266910","771267232","771267578","771305050","771305747","771307293","771316210","771324998","771325066","771359010","771371300","771372054","771377311","771377991","771383243","771387806","771388482","771401855","771412029","771412106","771412118","771412133","771413507","771418740","771419654","771419700","771428993","771429024","771436012","771439525","771440535","771441788","771442788","771445674","771446056","771446861","771450230","771454573","771466968","771467011","771467013","771467015","771468387","771472582","771484225","771484409","771488671","771489086","771489122","771489131","771489136","771489869","771490193","771490573","771491185","771491442","771491679","771492508","771492648","771493505","771493877","771496311","771498427","771501032","771501713","771501778","771503979","771504198","771506750","771511527","771512514"],
#           "publication-date": "06\/05\/2020",
#           "related-celebrity-ids": [],
#           "franchise": "",
#           "tags": ""        });
#     </script>
#
#     <script>
#         var mpscall = mpscall || {};
#         mpscall = {
#             "site":"rottentomatoes-web",
#             "field[env]": "production", // execution environment
#             "type": "guide",
#             "cat": "guide|Countdown",
#             "cag[hub]": "172375",
#         };
#
#         var mpsopts = {
#          "host":"mps.nbcuni.com",
#          "updatecorrelator":true
#         }
#
#         var BK = {};
#
#         BK.PageName="https:\/\/editorial.rottentomatoes.com\/guide\/best-black-movies-21st-century\/";
#         BK.SiteSection="guide";
#         BK.ArticleTags="";
#         BK.RelatedMovieId=["10283","10414","10577","11030","11438","126518499","12784","13267","13368","14819","152552156","155655104","15861","17495","1788","2132","358047697","49248977","493864880","770671119","770679318","770682608","770800373","770802637","770803691","770873459","771205918","771228631","771234052","771245718","771266910","771267232","771267578","771305050","771305747","771307293","771316210","771324998","771325066","771359010","771371300","771372054","771377311","771377991","771383243","771387806","771388482","771401855","771412029","771412106","771412118","771412133","771413507","771418740","771419654","771419700","771428993","771429024","771436012","771439525","771440535","771441788","771442788","771445674","771446056","771446861","771450230","771454573","771466968","771467011","771467013","771467015","771468387","771472582","771484225","771484409","771488671","771489086","771489122","771489131","771489136","771489869","771490193","771490573","771491185","771491442","771491679","771492508","771492648","771493505","771493877","771496311","771498427","771501032","771501713","771501778","771503979","771504198","771506750","771511527","771512514"];
#         BK.RelatedTalentId=[];
#         BK.RelatedTVSeriesId=[];
#
#         var mps=mps||{};mps._ext=mps._ext||{};mps._adsheld=[];mps._queue=mps._queue||{};mps._queue.mpsloaded=mps._queue.mpsloaded||[];mps._queue.mpsinit=mps._queue.mpsinit||[];mps._queue.gptloaded=mps._queue.gptloaded||[];mps._queue.adload=mps._queue.adload||[];mps._queue.adclone=mps._queue.adclone||[];mps._queue.adview=mps._queue.adview||[];mps._queue.refreshads=mps._queue.refreshads||[];mps.__timer=Date.now();mps.__intcode="v2";if(typeof mps.getAd!="function")mps.getAd=function(adunit){if(typeof adunit!="string")return false;var slotid="mps-getad-"+adunit.replace(/\W/g,"");if(!mps._ext||!mps._ext.loaded){mps._queue.gptloaded.push(function(){typeof mps._gptfirst=="function"&&mps._gptfirst(adunit,slotid);mps.insertAd("#"+slotid,adunit)});mps._adsheld.push(adunit)}return'<div id="'+slotid+'" class="mps-wrapper" data-mps-fill-slot="'+adunit+'"></div>'};(function(){head=document.head||document.getElementsByTagName("head")[0],mpsload=document.createElement("script");mpsload.src="//"+mpsopts.host+"/fetch/ext/load-"+mpscall.site+".js?nowrite=2";mpsload.id="mps-load";head.insertBefore(mpsload,head.firstChild)})();
#     </script>
#
#
#     <script type='text/javascript'>
#         var RT = RT || {};
#         RT.rtUrl = "https://www.rottentomatoes.com";
#         RT.rtApiUrl = "https://static.rottentomatoes.com";
#         var googletag = googletag || {};
#         googletag.cmd = googletag.cmd || [];
#         googletag.unitIds = [];
#         (function() {
#         var gads = document.createElement('script');
#         gads.async = true;
#         gads.type = 'text/javascript';
#         var useSSL = 'https:' == document.location.protocol;
#         gads.src = (useSSL ? 'https:' : 'http:') +
#         '//www.googletagservices.com/tag/js/gpt.js';
#         var node = document.getElementsByTagName('script')[0];
#         node.parentNode.insertBefore(gads, node);
#         })();
#     </script>
#
#     <script src="//cdn.optimizely.com/js/594670329.js"></script>
#
#     <!-- Facebook Pixel Code -->
#     <script>
#     !function(f,b,e,v,n,t,s){if(f.fbq)return;n=f.fbq=function()
#     {n.callMethod? n.callMethod.apply(n,arguments):n.queue.push(arguments)}
#     ;if(!f._fbq)f._fbq=n;
#     n.push=n;n.loaded=!0;n.version='2.0';n.queue=[];t=b.createElement(e);t.async=!0;
#     t.src=v;s=b.getElementsByTagName(e)[0];s.parentNode.insertBefore(t,s)}(window,
#     document,'script','https://connect.facebook.net/en_US/fbevents.js');
#     fbq('init', '1147905821962466');
#     fbq('track', 'PageView');
#     </script>
#     <noscript><img height="1" width="1" style="display:none"
#     src="https://www.facebook.com/tr?id=1147905821962466&ev=PageView&noscript=1"
#     /></noscript>
#     <!-- DO NOT MODIFY -->
#     <!-- End Facebook Pixel Code -->
#
#
#     <!-- Chartbeat Code -->
#     <script type="text/javascript">
#           var _sf_async_config = _sf_async_config || {};
#           /** CONFIGURATION START **/
#           _sf_async_config.uid = 64558; // ACCOUNT NUMBER
#           _sf_async_config.domain = 'rottentomatoes.com'; // DOMAIN
#           _sf_async_config.flickerControl = false;
#           _sf_async_config.useCanonical = true;
#           /** CONFIGURATION END **/
#           var _sf_startpt = (new Date()).getTime();
#     </script>
#     <script async src="//static.chartbeat.com/js/chartbeat_mab.js"></script>
#
#     <script type="text/javascript" src="//player.theplatform.com/pdk/dCK2IC/tpPdkController.js?pdk=5.7.5&logLevel=debug" onload="$pdk.bind(this, true); $pdk.controller.setIFrame(this, true);"></script>
#
#
#     <script src="//assets.adobedtm.com/a5fa26c3da5356c4d77ae8244dc4eb5096e2f4b0/satelliteLib-cbce2cb5d7b476a55d4d651acf340e0592b4f00c.js"></script>    <link rel='dns-prefetch' href='//editorial.rottentomatoes.com' />
# <link rel='dns-prefetch' href='//s.w.org' />
# <link rel="alternate" type="application/rss+xml" title="Rotten Tomatoes - Movie and TV News &raquo; The 100 Best Black Movies of the 21st Century &#8211; The Greatest New African American Films Comments Feed" href="https://editorial.rottentomatoes.com/guide/best-black-movies-21st-century/feed/" />
# 		<script type="text/javascript">
# 			window._wpemojiSettings = {"baseUrl":"https:\/\/s.w.org\/images\/core\/emoji\/2.2.1\/72x72\/","ext":".png","svgUrl":"https:\/\/s.w.org\/images\/core\/emoji\/2.2.1\/svg\/","svgExt":".svg","source":{"concatemoji":"https:\/\/editorial.rottentomatoes.com\/wp-includes\/js\/wp-emoji-release.min.js?ver=4.7.3"}};
# 			!function(a,b,c){function d(a){var b,c,d,e,f=String.fromCharCode;if(!k||!k.fillText)return!1;switch(k.clearRect(0,0,j.width,j.height),k.textBaseline="top",k.font="600 32px Arial",a){case"flag":return k.fillText(f(55356,56826,55356,56819),0,0),!(j.toDataURL().length<3e3)&&(k.clearRect(0,0,j.width,j.height),k.fillText(f(55356,57331,65039,8205,55356,57096),0,0),b=j.toDataURL(),k.clearRect(0,0,j.width,j.height),k.fillText(f(55356,57331,55356,57096),0,0),c=j.toDataURL(),b!==c);case"emoji4":return k.fillText(f(55357,56425,55356,57341,8205,55357,56507),0,0),d=j.toDataURL(),k.clearRect(0,0,j.width,j.height),k.fillText(f(55357,56425,55356,57341,55357,56507),0,0),e=j.toDataURL(),d!==e}return!1}function e(a){var c=b.createElement("script");c.src=a,c.defer=c.type="text/javascript",b.getElementsByTagName("head")[0].appendChild(c)}var f,g,h,i,j=b.createElement("canvas"),k=j.getContext&&j.getContext("2d");for(i=Array("flag","emoji4"),c.supports={everything:!0,everythingExceptFlag:!0},h=0;h<i.length;h++)c.supports[i[h]]=d(i[h]),c.supports.everything=c.supports.everything&&c.supports[i[h]],"flag"!==i[h]&&(c.supports.everythingExceptFlag=c.supports.everythingExceptFlag&&c.supports[i[h]]);c.supports.everythingExceptFlag=c.supports.everythingExceptFlag&&!c.supports.flag,c.DOMReady=!1,c.readyCallback=function(){c.DOMReady=!0},c.supports.everything||(g=function(){c.readyCallback()},b.addEventListener?(b.addEventListener("DOMContentLoaded",g,!1),a.addEventListener("load",g,!1)):(a.attachEvent("onload",g),b.attachEvent("onreadystatechange",function(){"complete"===b.readyState&&c.readyCallback()})),f=c.source||{},f.concatemoji?e(f.concatemoji):f.wpemoji&&f.twemoji&&(e(f.twemoji),e(f.wpemoji)))}(window,document,window._wpemojiSettings);
# 		</script>
# 		<style type="text/css">
# img.wp-smiley,
# img.emoji {
# 	display: inline !important;
# 	border: none !important;
# 	box-shadow: none !important;
# 	height: 1em !important;
# 	width: 1em !important;
# 	margin: 0 .07em !important;
# 	vertical-align: -0.1em !important;
# 	background: none !important;
# 	padding: 0 !important;
# }
# </style>
# <link rel='stylesheet' id='opinionstage-style-css'  href='https://editorial.rottentomatoes.com/wp-content/plugins/social-polls-by-opinionstage/opinionstage-style-common.css?ver=4.7.3' type='text/css' media='all' />
# <link rel='stylesheet' id='opinionstage-font-style-css'  href='https://editorial.rottentomatoes.com/wp-content/plugins/social-polls-by-opinionstage/opinionstage-font.css?ver=4.7.3' type='text/css' media='all' />
# <link rel='stylesheet' id='media-credit-css'  href='https://editorial.rottentomatoes.com/wp-content/plugins/media-credit/public/css/media-credit.css?ver=3.1.5' type='text/css' media='all' />
# <link rel='stylesheet' id='stylesheet-css'  href='https://editorial.rottentomatoes.com/wp-content/themes/RottenTomatoes/style.css?ver=1' type='text/css' media='all' />
# <link rel='stylesheet' id='mediaelement-css'  href='https://editorial.rottentomatoes.com/wp-includes/js/mediaelement/mediaelementplayer.min.css?ver=2.22.0' type='text/css' media='all' />
# <link rel='stylesheet' id='wp-mediaelement-css'  href='https://editorial.rottentomatoes.com/wp-includes/js/mediaelement/wp-mediaelement.min.css?ver=4.7.3' type='text/css' media='all' />
# <link rel='stylesheet' id='views-pagination-style-css'  href='https://editorial.rottentomatoes.com/wp-content/plugins/wp-views/embedded/res/css/wpv-pagination.css?ver=2.3.1' type='text/css' media='all' />
# <style id='views-pagination-style-inline-css' type='text/css'>
# .wpv-sort-list-dropdown.wpv-sort-list-dropdown-style-default > span.wpv-sort-list,.wpv-sort-list-dropdown.wpv-sort-list-dropdown-style-default .wpv-sort-list-item {border-color: #cdcdcd;}.wpv-sort-list-dropdown.wpv-sort-list-dropdown-style-default .wpv-sort-list-item a {color: #444;background-color: #fff;}.wpv-sort-list-dropdown.wpv-sort-list-dropdown-style-default a:hover,.wpv-sort-list-dropdown.wpv-sort-list-dropdown-style-default a:focus {color: #000;background-color: #eee;}.wpv-sort-list-dropdown.wpv-sort-list-dropdown-style-default .wpv-sort-list-item.wpv-sort-list-current a {color: #000;background-color: #eee;}.wpv-sort-list-dropdown.wpv-sort-list-dropdown-style-grey > span.wpv-sort-list,.wpv-sort-list-dropdown.wpv-sort-list-dropdown-style-grey .wpv-sort-list-item {border-color: #cdcdcd;}.wpv-sort-list-dropdown.wpv-sort-list-dropdown-style-grey .wpv-sort-list-item a {color: #444;background-color: #eeeeee;}.wpv-sort-list-dropdown.wpv-sort-list-dropdown-style-grey a:hover,.wpv-sort-list-dropdown.wpv-sort-list-dropdown-style-grey a:focus {color: #000;background-color: #e5e5e5;}.wpv-sort-list-dropdown.wpv-sort-list-dropdown-style-grey .wpv-sort-list-item.wpv-sort-list-current a {color: #000;background-color: #e5e5e5;}.wpv-sort-list-dropdown.wpv-sort-list-dropdown-style-blue > span.wpv-sort-list,.wpv-sort-list-dropdown.wpv-sort-list-dropdown-style-blue .wpv-sort-list-item {border-color: #0099cc;}.wpv-sort-list-dropdown.wpv-sort-list-dropdown-style-blue .wpv-sort-list-item a {color: #444;background-color: #cbddeb;}.wpv-sort-list-dropdown.wpv-sort-list-dropdown-style-blue a:hover,.wpv-sort-list-dropdown.wpv-sort-list-dropdown-style-blue a:focus {color: #000;background-color: #95bedd;}.wpv-sort-list-dropdown.wpv-sort-list-dropdown-style-blue .wpv-sort-list-item.wpv-sort-list-current a {color: #000;background-color: #95bedd;}
# </style>
# <script type='text/javascript' src='https://editorial.rottentomatoes.com/wp-includes/js/jquery/jquery.js?ver=1.12.4'></script><script>jQueryWP = jQuery;</script>
# <script type='text/javascript' src='https://editorial.rottentomatoes.com/wp-includes/js/jquery/jquery-migrate.min.js?ver=1.4.1'></script>
# <script type='text/javascript' src='https://editorial.rottentomatoes.com/wp-content/plugins/wp-google-analytics-events/js/ga-scroll-events.js?ver=2.4.1'></script>
# <script type='text/javascript'>
# /* <![CDATA[ */
# var sranalytics = {"version":"0.1.4","pid":"563cb84e736b79c3db00006c","iframe":"0","title":"The 100 Best Black Movies of the 21st Century - The Greatest New African American Films","url":"https:\/\/editorial.rottentomatoes.com\/guide\/best-black-movies-21st-century\/","date":"2020-06-05 16:00:58","channels":[],"tags":[],"authors":[""]};
# /* ]]> */
# </script>
# <script type='text/javascript' src='https://editorial.rottentomatoes.com/wp-content/plugins/sranalytics_wordpress-0.1.5/javascripts/sranalytics.js?ver=4.7.3'></script>
# <link rel='https://api.w.org/' href='https://editorial.rottentomatoes.com/wp-json/' />
# <link rel="EditURI" type="application/rsd+xml" title="RSD" href="https://editorial.rottentomatoes.com/xmlrpc.php?rsd" />
# <link rel="wlwmanifest" type="application/wlwmanifest+xml" href="https://editorial.rottentomatoes.com/wp-includes/wlwmanifest.xml" />
# <link rel='prev' title='The Best TV Shows of 2020 (So Far)' href='https://editorial.rottentomatoes.com/guide/best-tv-shows-of-2020/' />
# <link rel='next' title='110 Important Films About the Black Experience' href='https://editorial.rottentomatoes.com/guide/important-films-about-the-black-experience/' />
# <meta name="generator" content="WordPress 4.7.3" />
# <link rel="canonical" href="https://editorial.rottentomatoes.com/guide/best-black-movies-21st-century/" />
# <link rel='shortlink' href='https://editorial.rottentomatoes.com/?p=172375' />
# <link rel="alternate" type="application/json+oembed" href="https://editorial.rottentomatoes.com/wp-json/oembed/1.0/embed?url=https%3A%2F%2Feditorial.rottentomatoes.com%2Fguide%2Fbest-black-movies-21st-century%2F" />
# <link rel="alternate" type="text/xml+oembed" href="https://editorial.rottentomatoes.com/wp-json/oembed/1.0/embed?url=https%3A%2F%2Feditorial.rottentomatoes.com%2Fguide%2Fbest-black-movies-21st-century%2F&#038;format=xml" />
# <style type="text/css">.countdown-adjusted-score { display:none }
#
# .articleContentBody {
#     background-color: #393939;
#     padding-bottom: 50px;
# }
#
# .articleContentBody .info {
#     margin-right:10px
# }
#
# .articleContentBody h1 {
#     color: white;
#     font-size: 32px;
#     font-weight: normal;
#     padding: 20px 10px;
#     margin: 0px;
# }
#
# .articleContentBody p {
#     padding-left: 10px;
#     color: white;}
#
# .articleContentBody .info {
#     padding: 5px 0;
#     color: white;}
#
# .articleContentBody .descriptor {
#     font-weight: bold;
# }
#
# .tMeterScore, .subtle {
#     color: #fff;
# }
#
# .countdown-item {
#    padding: 20px 0px;
#    border-top-style: solid;
#    border-top-width: 1px;
#    border-top-color: white;
# }
#
# .articleContentBody .countdown-item-content a {
#     color:#fff!important;
#  }
# .articleContentBody .countdown-item-content a:hover {
#     color:#0C89CA !important;
#     text-decoration: none;
# }
# .article_poster {
#     border:0 !important;
#     padding-left: 10px;
# }
#
#
#
# .countdown-index {
# 	background: #FFF;
# 	width: 60px;
# 	height: 54px;
# 	text-align: center;
#         float:right;
# 	vertical-align: middle;
# 	font-size: 24px;
# 	font-weight: bold;
# 	border-radius: 5px;
# 	padding: 10px;
#         margin-right: 15px;
#         margin-bottom:10px
# }
#
# @media (max-width:767px) {
#     .countdown-index {
#         position: absolute;
#         bottom: 230px;
#         margin-left: 17px;
#     }
# }
#
# .subtle { color:#fff!important }
# .countdown-index { text-indent:-5px!important }</style>		<style>
# 		.getty.alignleft {
# 			margin-right: 5px;
# 		}
# 		.getty.alignright {
# 			margin-left: 5px;
# 		}
# 		</style>
# 		<link rel='https://github.com/WP-API/WP-API' href='https://editorial.rottentomatoes.com/wp-json' />
#         <script>
#                 if (typeof ga === 'undefined') {
#                   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#                   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#                   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#                   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#                   ga('create','UA-2265251-1', 'rt-editorial-prod.aws.prod.flixster.com');                  ga('send', 'pageview');
#                                 }
#             </script>
#   <script>!function(a){var e="https://s.go-mpulse.net/boomerang/",t="addEventListener";if("False"=="True")a.BOOMR_config=a.BOOMR_config||{},a.BOOMR_config.PageParams=a.BOOMR_config.PageParams||{},a.BOOMR_config.PageParams.pci=!0,e="https://s2.go-mpulse.net/boomerang/";if(window.BOOMR_API_key="FY54K-R3QDX-VKS32-UEVJ8-QAXP2",function(){function n(e){a.BOOMR_onload=e&&e.timeStamp||(new Date).getTime()}if(!a.BOOMR||!a.BOOMR.version&&!a.BOOMR.snippetExecuted){a.BOOMR=a.BOOMR||{},a.BOOMR.snippetExecuted=!0;var i,o,_,r=document.createElement("iframe");if(a[t])a[t]("load",n,!1);else if(a.attachEvent)a.attachEvent("onload",n);r.src="javascript:void(0)",r.title="",r.role="presentation",(r.frameElement||r).style.cssText="width:0;height:0;border:0;display:none;",_=document.getElementsByTagName("script")[0],_.parentNode.insertBefore(r,_);try{o=r.contentWindow.document}catch(O){i=document.domain,r.src="javascript:var d=document.open();d.domain='"+i+"';void(0);",o=r.contentWindow.document}o.open()._l=function(){var a=this.createElement("script");if(i)this.domain=i;a.id="boomr-if-as",a.src=e+"FY54K-R3QDX-VKS32-UEVJ8-QAXP2",BOOMR_lstart=(new Date).getTime(),this.body.appendChild(a)},o.write("<bo"+'dy onload="document._l();">'),o.close()}}(),"".length>0)if(a&&"performance"in a&&a.performance&&"function"==typeof a.performance.setResourceTimingBufferSize)a.performance.setResourceTimingBufferSize();!function(){if(BOOMR=a.BOOMR||{},BOOMR.plugins=BOOMR.plugins||{},!BOOMR.plugins.AK){var e=""=="true"?1:0,t="",n="eyaqdqqfadraaiabavmqaglysfpokjqj-f-31be1d4e2-clienttons-s.akamaihd.net",i={"ak.v":"27","ak.cp":"899812","ak.ai":parseInt("576128",10),"ak.ol":"0","ak.cr":138,"ak.ipv":6,"ak.proto":"","ak.rid":"32a4b001","ak.r":28566,"ak.a2":e,"ak.m":"dscx","ak.n":"essl","ak.bpcip":"2601:1c2:500:e200::","ak.cport":57603,"ak.gh":"23.47.144.118","ak.quicv":"","ak.tlsv":"tls1.3","ak.0rtt":"","ak.csrc":"-","ak.acc":"reno","ak.t":"1592075785","ak.ak":"hOBiQwZUYzCg5VSAfCLimQ==...","ak.pv":"1"};if(""!==t)i["ak.ruds"]=t;var o={i:!1,av:function(e){var t="http.initiator";if(e&&(!e[t]||"spa_hard"===e[t]))i["ak.feo"]=void 0!==a.aFeoApplied?1:0,BOOMR.addVar(i)},rv:function(){var a=["ak.bpcip","ak.cport","ak.cr","ak.csrc","ak.gh","ak.ipv","ak.m","ak.n","ak.ol","ak.proto","ak.quicv","ak.tlsv","ak.0rtt","ak.r","ak.acc","ak.t"];BOOMR.removeVar(a)}};BOOMR.plugins.AK={akVars:i,akDNSPreFetchDomain:n,init:function(){if(!o.i){var a=BOOMR.subscribe;a("before_beacon",o.av,null,null),a("onbeacon",o.rv,null,null),o.i=!0}return this},is_complete:function(){return!0}}}}()}(window);</script></head>
#     <body class="body">
#         <!-- Google Tag Manager -->
# <noscript><iframe src="//www.googletagmanager.com/ns.html?id=GTM-KZKXN6"
# height="0" width="0" style="display:none;visibility:hidden"></iframe></noscript>
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# '//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-KZKXN6');</script>
# <!-- End Google Tag Manager -->
# <div id="navMenu" class="modal fade" role="dialog" aria-labelledby="navMenu">
#     <div class="modal-dialog">
#         <div class="modal-content">
#             <div class="modal-body">
#                 <button type="button" class="close" data-dismiss="modal" aria-label="Close">
#                     <span class="glyphicon glyphicon-remove" />
#                 </button>
#                 <div class="pull-left">
#                     <ul class="list-inline social">
#                         <li><a id="header-facebook-social-link" class="unstyled fontelloIcon icon-facebook-squared" href="https://www.facebook.com/rottentomatoes" target="_blank"></a></li>
#                         <li><a id="header-twitter-social-link" class="unstyled fontelloIcon icon-twitter" href="https://twitter.com/rottentomatoes" target="_blank"></a></li>
#                     </ul>
#                 </div>
#                 <div class="items">
#                     <div class="item">
#                         <a class="homeTab unstyled navLink fullLink" href="https://www.rottentomatoes.com/">
#                             Home
#                         </a>
#                     </div>
#                     <div class="item">
#                         <a class="boxofficeTab unstyled navLink fullLink" href="https://www.rottentomatoes.com/lists/theater/">
#                             Top Box Office
#                         </a>
#                     </div>
#                     <div class="item">
#                         <a class="theatersTab unstyled navLink fullLink" href="https://www.rottentomatoes.com/theaters/">
#                             Tickets &amp; Showtimes
#                         </a>
#                     </div>
#                     <div class="item">
#                         <a class="dvdTab unstyled navLink fullLink" href="https://www.rottentomatoes.com/lists/dvd/">
#                             DVD &amp; Streaming
#                         </a>
#                     </div>
#                     <div class="item">
#                         <a class="tvTab unstyled navLink fullLink" href="https://www.rottentomatoes.com/lists/tv/">
#                             TV
#                         </a>
#                     </div>
#                     <div class="item">
#                         <a class="newsTab unstyled navLink fullLink" href="https://editorial.rottentomatoes.com">
#                             News
#                         </a>
#                     </div>
# <!--                    <div class="item">-->
# <!--                        <a class="newsletterTab unstyled navLink fullLink" href="--><!--/newsletter/">-->
# <!--                            Join Newsletter-->
# <!--                        </a>-->
# <!--                    </div>-->
#                 </div>
#                 <div class="loginArea">
#                     <a href="#signup" data-toggle="modal" data-target="#signup" class="signupLink login">SIGN UP</a>
#                     <a href="#login" data-toggle="modal" data-target="#login" class="loginLink login">LOG IN</a>
#                     <div class="userProfile" style="display:none">
#                         <a class="userProfileLink">
#                             <div class="media">
#                                 <div class="pull-left">
#                                     <img class="media-object" src="//graph.facebook.com/v2.2/100001988417196/picture"/>
#                                 </div>
#                                 <div class="pull-right">
#                                     <span class="glyphicon glyphicon-cog"/>
#                                 </div>
#                                 <div class="media-body">
#                                     <span class="name">Jester McGree</span>
#                                 </div>
#                             </div>
#                         </a>
#                     </div>
#                     <div class="logoutRow" style="display:none">
#                         <a class="logout" href="/logout/">
#                             Logout
#                         </a>
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# </div>
# <div class="body_main container">
#     <div id="top_leaderboard_wrapper" class="leaderboard_wrapper">
#         <div class="leaderboard_helper">
#             <div id="leaderboard_top_ad"></div>
#             <script>
#                 //--RESPONSIVE AD SWITCHING (DIFFERENT CONTAINERS)
#                 var mps=mps||{}; mps._queue=mps._queue||{}; mps._queue.gptloaded=mps._queue.gptloaded||[];
#                 mps._queue.gptloaded.push(function() {
#                     if (mps.getResponsiveSet() =='0') { //MOBILE
#                         mps.insertAd('#leaderboard_top_ad','mbanner');
#                     } else { //DESKTOP or TABLET
#                         mps.insertAd('#leaderboard_top_ad','topbanner');
#                     }
#                 });
#             </script>
#         </div>
#     </div>
#     <div class="header_main container">
#         <div id="navbar" class="navbar navbar-rt" role="navigation">
#             <div class="navbar-header pull-right hidden-xs">
#                 <div class="header_links">
#                     <a id="header-whats-the-tomatometer" href="https://www.rottentomatoes.com/about/">What's the Tomatometer?&reg;</a>
#                     <a id="header-top-bar-critics" href="https://www.rottentomatoes.com/critics/">RT Critics</a>
#                     <!--<a id="header-top-bar-newsletter" href="--><!--/newsletter/">Newsletter</a>-->
#                 </div>
#             </div>
#             <div id="header_brand_column" class="col-sm-13 col-full-xs">
#                 <div class="hidden-xs desktopNav">
#                     <!-- Logo -->
#                     <div class="navbar-brand">
#                         <a id="header-rt-logo" href="https://www.rottentomatoes.com/">
#                             <img src="//staticv2-4.rottentomatoes.com/static/images/logos/rtlogo.png" />
#                         </a>
#                     </div>
#                     <div id="rt_logo_ad" style="display:none;"></div>
#                     <script>
#                         var mps=mps||{}; mps._queue=mps._queue||{}; mps._queue.gptloaded=mps._queue.gptloaded||[];
#                         mps._queue.gptloaded.push(function() {
#                             if (mps.getResponsiveSet() !='0') { //DESKTOP or TABLET
#                                 mps.rt.insertlogo('#rt_logo_ad', 'ploc=rtlogo;');
#                             }
#                         });
#                     </script>
#                     <!-- Search box -->
#                     <div id="desktop-search-root">
#                         <form action="/search/" method="get">
#                             <div class="navbar-searchbox main">
#                                 <div class="input-group">
#                                     <input name="search" type="text" class="form-control" placeholder="Search movies, TV, actors, more..." name="srch-term" id="search-term">
#                                     <div class="input-group-btn">
#                                         <button type="submit" class="btn btn-default searchBtn">
#                                             <em class="glyphicon glyphicon-search"></em>
#                                         </button>
#                                     </div>
#                                     <div class="navbar-close">
#                                         <button type="button" class="btn btn-default">
#                                             <span class="glyphicon glyphicon-remove" />
#                                         </button>
#                                     </div>
#                                 </div>
#                             </div>
#                         </form>
#                     </div>
#                 </div>
#                 <div id="mobile-nav" class="visible-xs mobileNav">
#                     <div>
#                         <a id="mobile-search-button">
#                             <button class="pull-right navbar-button searchButton">
#                                 <em class="glyphicon glyphicon-search white"></em>
#                             </button>
#                         </a>
#                     </div>
#                     <div class="navbar-brand">
#                         <a id="header-rt-logo" href="https://www.rottentomatoes.com/">
#                             <img src="//staticv2-4.rottentomatoes.com/static/images/logos/rtlogo.png" />
#                         </a>
#                     </div>
#                     <div class="mob-nav-bottom clearfix">
#                         <ul id="nav-list" class="nav-list">
#                             <li class="nav-item">
#                                 <a href="https://www.rottentomatoes.com"><i class=" fontelloIcon icon-home"></i>Home</a>
#                             </li>
#                             <li class="nav-item">
#                                 <a href="https://www.rottentomatoes.com/lists/theater/"><i class=" fontelloIcon icon-boxoffice"></i>Box Office</a>
#                             </li>
#                             <li class="nav-item">
#                                 <a href="https://www.rottentomatoes.com/lists/tv/"><i class=" fontelloIcon icon-tv2"></i>TV</a>
#                             </li>
#                             <li class="nav-item">
#                                 <a href="https://www.rottentomatoes.com/lists/dvd/"><i class=" fontelloIcon icon-redeem"></i>DVD</a>
#                             </li>
#                             <li class="nav-item">
#                                 <a id="menu-btn" class="menu-btn" href="#">
#                                     <i class=" fontelloIcon icon-more"></i>MORE
#                                 </a>
#                             </li>
#                         </ul>
#                     </div>
#                     <div id="mobile-nav-overlay" class="mobile-nav-overlay">
#                         <!--mobile dropdown-->
#                         <ul class="mobile-menu-panel">
#                             <li class="nav-item"><a href="https://editorial.rottentomatoes.com">News</a></li>
#                             <li class="nav-item clearfix d-block">
#                                 <!-- <div class="login-signup-box pull-left">
#                                     <a id="mobile-signup-btn" data-toggle="modal" data-target="#signup" class="signupLink login btn-login-signup" href="#signup">SIGN UP</a>
#                                     <a id="mobile-login-btn" data-toggle="modal" data-target="#login" class="loginLink login btn-login-signup" href="#login">LOG IN</a>
#                                 </div> -->
#                                 <div class="social-media-box pull-right">
#                                     <a href="https://www.facebook.com/rottentomatoes">
#                                         <i class="fontelloIcon icon-facebook-squared" aria-hidden="true"></i>
#                                     </a>
#                                     <a href="https://twitter.com/rottentomatoes">
#                                         <i class="fontelloIcon icon-twitter" aria-hidden="true"></i>
#                                     </a>
#                                 </div>
#                             </li>
#                         </ul>
#                         <!--mobile dropdown end-->
#                     </div>
#                 </div>
#             <!--Mobile Nav END-->
#             </div>
#             <div id="menu" class="navbar-nav col-sm-11 hidden-xs">
#                 <ul class="list-inline">
#                     <li id='movieMenuTab' class='menuHeader center noSpacing' > <a id='movieMenu' class='h2' href='https://www.rottentomatoes.com/browse/'>Movies &amp; DVDS<span class='fontelloIcon icon-down-dir'></span></a> </li>
#                     <li id='tvMenuTab' class='menuHeader center noSpacing' > <a id='tvMenu' class='h2' href='https://www.rottentomatoes.com/tv/'>TV<span class='fontelloIcon icon-down-dir'></span></a> </li>
#                     <li id='newsMenuTab' class='menuHeader center noSpacing' > <a id='newsMenu' class='h2' href='https://editorial.rottentomatoes.com'>News<span class='fontelloIcon icon-down-dir'></span></a> </li>
#                     <li class='menuHeader center noSpacing' style='border-radius: 5px' id='header-tickets-showtimes'> <a id='ticketingMenu' class='h2' href='https://www.rottentomatoes.com/showtimes/?adid=nav_TS' class='menuHeader'>Tickets &amp; Showtimes</a> </li>
#                 </ul>
#             </div>
#         </div>
#         <div class='trendingBar hidden-xs'>
#             <div class='fr'>
#                 <ul id="trending_bar_social" class='list-inline social'>
#                     <li class='header'>Follow Us</li>
#                     <li><a id='header-twitter-social-link' class='unstyled trendingLink fontelloIcon icon-twitter white' href='https://twitter.com/rottentomatoes' target='_blank'></a></li>
#                     <li><a id='header-facebook-social-link' class='unstyled trendingLink fontelloIcon icon-facebook-squared white' href='https://www.facebook.com/rottentomatoes' target='_blank'></a></li>
#                     <li><a id='header-google-social-link' class='unstyled trendingLink fontelloIcon icon-gplus white' href='https://plus.google.com/+RottenTomatoes' target='_blank'></a></li>
#                     <li><a id='header-youtube-social-link' class='unstyled trendingLink fontelloIcon icon-youtube-play white' href='https://www.youtube.com/user/rottentomatoes' target='_blank'></a></li>
#                     <li><a id='header-tumblr-social-link' class='unstyled trendingLink fontelloIcon icon-tumblr white' href='https://rottentomatoes.tumblr.com/' target='_blank'></a></li>
#                 </ul>
#                 <div id="trending_bar_ad" style="display:none;"></div>
#                 <script>
#                     var mps=mps||{}; mps._queue=mps._queue||{}; mps._queue.gptloaded=mps._queue.gptloaded||[];
#                     mps._queue.gptloaded.push(function() {
#                         if (mps.getResponsiveSet() !='0') { //DESKTOP or TABLET
#                             mps.insertAd('#trending_bar_ad','trendinggraphic');
#                         }
#                     });
#                 </script>
#             </div>
#             <ul class="list-inline trendingEl">
#                 <li class="header">Trending on RT</li>
#             </ul>
#         </div>
#
#         <!-- start content container -->
#         <div style="min-height: 528px; background: white;" class="container body_main">
#                         <div id="article_main_body" class="col col-left-center col-full-xs article_body best-black-movies-21st-century">
#                 <div class="panel-rt panel-box article_body">
#
#                         <div id="social-tools-widget">
#                             <a href="#"><img src="https://static.rottentomatoes.com/static/images/social/social_fb_like.png" class="social-tools-facebook-like fb_like"></a>
#                             <a href="#"><img src="https://static.rottentomatoes.com/static/images/social/social_fb_share.png" class="social-tools-facebook-share"></a>
#                             <a href="#"><img src="https://static.rottentomatoes.com/static/images/social/social_twitter.png" class="social-tools-twitter"></a>
#                             <a href="#"><img src="https://static.rottentomatoes.com/static/images/social/social_google.png" class="social-tools-googleplus"></a>
#                         </div>
#
#                     <div class="articleContentBody">
#                                                 <img class="aligncenter wp-image-137479 size-full" src="https://s3-us-west-2.amazonaws.com/flx-editorial-wordpress/wp-content/uploads/2020/01/31131254/700GetOut2.jpg" width="700" height="250" /><div style="display: block;" class="media-credit image-text">(Photo by Uniersal/ courtesy Everett Collection)</div>
# <h1>The 100 Best Black Movies of the 21st Century</h1>
# <p>Rotten Tomatoes is celebrating the work of Black filmmakers and performers and the stories they have brought to our theaters over the past 20-plus years. In this guide to the best-reviewed African American movies of the 21st Century – that’s from 2000 all the way to now – you’ll find some of the most incredible voices working in movies today, and some of the most game-changing, industry-shaking films to hit theaters in decades. Think titles like Ryan Coogler’s <em>Black Panther</em>, the fourth highest-grossing movie of all time at the U.S. box office. Or Gina Prince-Bythewood’s seminal star-making romance, <em>Love and Basketball. </em>Or <em>Moonlight</em>, which made history as the first film with an all-black cast to win Best Picture at the Academy Awards in 2017. Or Ava DuVernay&#8217;s <em>Selma</em>, which at 99% on the Tomatometer remains one of the most critically acclaimed films of all time.</p>
# <p>Alongside the work of longtime industry veterans like Spike Lee, you’ll find incredible debut features, like Dee Rees’ <em>Pariah</em>, Justin Simien’s <em>Dear White People,</em> Boots Riley’s <em>Sorry to Bother You</em>, Phillip Youmens’ <em>Burning Cane</em>, which he directed while still in high school, and, of course, Jordan Peele&#8217;s Oscar-winning social thriller <em>Get Out</em> and his follow-up, <em>Us.</em> You’ll also discover documentaries that have stirred the national conversation – DuVernay’s <em>13th</em>, Ezra Edelman’s <em>O.J.: Made In America</em> – alongside recent mega hits that, like <em>Black Panther</em>, alerted Hollywood’s decision-makers to the fact that there was a huge audience for stories made by Black filmmakers, featuring Black actors, telling Black stories: Malcolm D. Lee’s <em>Girls Trip</em>, F. Gary Gray’s <em>Straight Outta Compton</em>.</p>
# <p>To compile our list, we chose the top 100 Certified Fresh Black films, according to the Tomatometer, released in theaters since 2000. We defined Black films as those that centered on African American stories and African American characters, or – as in the case of <em>Black Panther </em>– <em></em>were made by Black filmmakers and were embraced by African American audiences; there are instances of films here made by non-Black filmmakers (<em>Django Unchained</em>, <em>Detroit</em>, and <em>Get On Up </em>for example), but the top half of the list is dominated by Black writers and directors. </p>
# <p>We did not include straight-to-streaming or TV movies unless, like <em>13th</em> did, they had some sort of theatrical release, even just an Oscar-qualifying run, and did not include comedy specials. We ranked the list by Adjusted Tomatometer, which takes into account year of release and number of reviews collected to weight the ratings.</p>
# <p>Below is the result of all that compiling: our guide to the best Black films of the century (so far!). It’s chock full of laughs, thrills, tears, and insight. Enjoy, and if you want to tell us what you think of the list, think we’ve missed a title, or want to celebrate a film that didn’t quite meet the Certified Fresh criteria, let us know in the comments.</p>
# <p>
#         <div id='row-index-100' class='row countdown-item' style='padding-left: 10px;'>
#             <div class='countdown-index-resposive'>#100</div>
#             <div class='col-sm-6 col-full-xs'>
#               <a class='article_movie_poster' href='https://www.rottentomatoes.com/m/keanu_2016/'>
#                   <div><img class='article_poster' src='https://resizing.flixster.com/8xrQE1_7myLIepLNtnbKme3WQCY=/180x267/v1.bTsxMTgxOTYzMjtqOzE4NDczOzIwNDg7Mjc2NDs0MDk2' alt='' sborder='' style='border-color: #EEEEEE; border-style: solid; border-width: 1px;'></div>
#               </a>
#             </div>
#             <div class='col-sm-18 col-full-xs countdown-item-content'>
#                 <div class='row countdown-item-title-bar'>
#                     <div class='col-sm-20 col-full-xs' style='height: 100%;' >
#                         <div class='article_movie_title' style='float: left;'>
#                           <div><h2><a href='https://www.rottentomatoes.com/m/keanu_2016/'>Keanu</a> <span class='subtle start-year'>(2016)</span> </br><span title='Certified Fresh' class='icon tiny certified'></span> <span class='tMeterScore'>77%</span></h2></div>
#                         </div>
#                     </div>
#                     <div class='col-sm-4 col-full-xs' style='height: 100%;'>
#                         <div class='countdown-index'>#100</div>
#                     </div>
#                 </div>
#                 <div class='row countdown-item-details'>
#                     <div class='col-sm-24'>
#                         <div class='info countdown-adjusted-score'><span class='descriptor'>Adjusted Score: </span>83.474% <span class='glyphicon glyphicon-question-sign' rel='tooltip' data-toggle='tooltip' data-placement='top' data-html='true' title='' data-original-title='The Adjusted Score comes from a weighted formula (Bayesian) that we use that accounts for variation in the number of reviews per movie.'></span></div>
#                         <div class='info critics-consensus'><span class='descriptor'>Critics Consensus:</span> Keanu's absurd premise and compulsively watchable starring duo add up to an agreeably fast-paced comedy that hits more than enough targets to make up for the misses.</div>
#                         <div class='info synopsis'><span class='descriptor'>Synopsis:</span> Keegan-Michael Key and Jordan Peele star in this comedy as two friends posing as drug dealers to get back a...<a class='' target='_top' data-pageheader=''  href='https://www.rottentomatoes.com/m/keanu_2016/'> [More]</a></div>
#                         <div class='info cast'>
#                 <span class='descriptor'>Starring:</span> <a class='' href=/celebrity/keegan_michael_key/>Keegan-Michael Key</a>, <a class='' href=/celebrity/jordan_peele/>Jordan Peele</a>, <a class='' href=/celebrity/tiffany_haddish/>Tiffany Haddish</a>, <a class='' href=/celebrity/1059159-method_man/>Method Man</a></div>
#                         <div class='info director'>
#                 <span class='descriptor'>Directed By:</span> <a class='' href=/celebrity/peter_atencio/>Peter Atencio</a></div>
#                     </div>
#                 </div>
#             </div>
#         </div><br />
#
#         <div id='row-index-99' class='row countdown-item' style='padding-left: 10px;'>
#             <div class='countdown-index-resposive'>#99</div>
#             <div class='col-sm-6 col-full-xs'>
#               <a class='article_movie_poster' href='https://www.rottentomatoes.com/m/drumline/'>
#                   <div><img class='article_poster' src='https://resizing.flixster.com/AUwUTxNE2FIJ9hA53iyHgJN1g14=/180x240/v1.bTsxMTI5MDE5MTtqOzE4NTQxOzIwNDg7MTUxNTsyMDIw' alt='' sborder='' style='border-color: #EEEEEE; border-style: solid; border-width: 1px;'></div>
#               </a>
#             </div>
#             <div class='col-sm-18 col-full-xs countdown-item-content'>
#                 <div class='row countdown-item-title-bar'>
#                     <div class='col-sm-20 col-full-xs' style='height: 100%;' >
#                         <div class='article_movie_title' style='float: left;'>
#                           <div><h2><a href='https://www.rottentomatoes.com/m/drumline/'>Drumline</a> <span class='subtle start-year'>(2002)</span> </br><span title='Certified Fresh' class='icon tiny certified'></span> <span class='tMeterScore'>82%</span></h2></div>
#                         </div>
#                     </div>
#                     <div class='col-sm-4 col-full-xs' style='height: 100%;'>
#                         <div class='countdown-index'>#99</div>
#                     </div>
#                 </div>
#                 <div class='row countdown-item-details'>
#                     <div class='col-sm-24'>
# ...
#                 <li><a id="footer-api" class="unstyled trendingLink" href="https://developer.rottentomatoes.com">API</a></li>
#                 <li><a id="footer-licensing" class="unstyled trendingLink" href="https://www.rottentomatoes.com/help_desk/licensing/">Licensing</a></li>
#             </ul>
#         </div>
#         <div class="col-xs-7 subnav">
# <!--            <h2><span class="glyphicon glyphicon-envelope"></span>&nbsp;&nbsp;JOIN THE NEWSLETTER</h2>-->
# <!--            <div style="margin:10px 0">-->
# <!--                Get the freshest reviews, news, and more delivered right to your inbox!-->
# <!--            </div>-->
# <!--            <form id="newsletterSignup" action="--><!--/promo/newsletter-signup-confirm" method="POST" target="_blank">-->
# <!--                <div class="input-group">-->
# <!--                    <input name="email" type="text" class="form-control" placeholder="Enter your email address">-->
# <!--                    <span class="input-group-btn">-->
# <!--                        <button id="footer-newsletter-join" type="submit" class="btn btn-primary-rt">Join</button>-->
# <!--                    </span>-->
# <!--                </div>-->
# <!--            </form>-->
#         </div>
#         <div class="col-xs-8 subnav">
#             <h2>Follow Us</h2>
#             <div>
#                 <a id="footer-follow-us-twitter" class="unstyled trendingLink fontelloIcon icon-twitter footerIcon" href="https://twitter.com/rottentomatoes"></a>&nbsp;&nbsp;&nbsp;
#                 <a id="footer-follow-us-facebook" class="unstyled trendingLink fontelloIcon icon-facebook-squared footerIcon" href="https://www.facebook.com/rottentomatoes"></a>&nbsp;&nbsp;&nbsp;
#                 <a id="footer-follow-us-google" class="unstyled trendingLink fontelloIcon icon-gplus footerIcon" href="https://plus.google.com/+RottenTomatoes"></a>&nbsp;&nbsp;&nbsp;
#                 <a id="footer-follow-us-youtube" class="unstyled trendingLink fontelloIcon icon-youtube-play footerIcon" href="https://www.youtube.com/user/rottentomatoes"></a>&nbsp;&nbsp;&nbsp;
#                 <a id="footer-follow-us-tumblr" class="unstyled trendingLink fontelloIcon icon-tumblr footerIcon" href="https://rottentomatoes.tumblr.com/"></a>&nbsp;&nbsp;&nbsp;
#             </div>
#         </div>
#     </div>
#     <div class="subtle" style="padding:10px">
#         <span class="easteregg">Copyright © 2018 Fandango. All rights reserved.</span>
#         <a id="footer-privacy" href="http://www.fandango.com/PrivacyPolicy">Privacy Policy</a> |
#         <a id="footer-tos" href="http://www.fandango.com/terms-and-policies/">Terms and Policies</a> |
#         <a id="footer-ad-choices" href="http://www.aboutads.info/choices">Ad Choices</a>
#     </div>
# </div>
# <div id="mobileFoot" class="visible-xs-block">
#     <div id="footer_text">
#         <div class="white">Copyright&nbsp;&#169;&nbsp; 2018 Fandango. All rights reserved.</div>
#         <div>
#             <a class="footerLinks" href="http://www.fandango.com/terms">Terms of Service</a>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
#             <a class="footerLinks" href="http://www.fandango.com/privacy">Privacy Policy</a>
#         </div>
#     </div>
# </div>
# <script type="text/html" id="tmpl-wp-playlist-current-item">
# 	<# if ( data.image ) { #>
# 	<img src="{{ data.thumb.src }}" alt="" />
# 	<# } #>
# 	<div class="wp-playlist-caption">
# 		<span class="wp-playlist-item-meta wp-playlist-item-title">&#8220;{{ data.title }}&#8221;</span>
# 		<# if ( data.meta.album ) { #><span class="wp-playlist-item-meta wp-playlist-item-album">{{ data.meta.album }}</span><# } #>
# 		<# if ( data.meta.artist ) { #><span class="wp-playlist-item-meta wp-playlist-item-artist">{{ data.meta.artist }}</span><# } #>
# 	</div>
# </script>
# <script type="text/html" id="tmpl-wp-playlist-item">
# 	<div class="wp-playlist-item">
# 		<a class="wp-playlist-caption" href="{{ data.src }}">
# 			{{ data.index ? ( data.index + '. ' ) : '' }}
# 			<# if ( data.caption ) { #>
# 				{{ data.caption }}
# 			<# } else { #>
# 				<span class="wp-playlist-item-title">&#8220;{{{ data.title }}}&#8221;</span>
# 				<# if ( data.artists && data.meta.artist ) { #>
# 				<span class="wp-playlist-item-artist"> &mdash; {{ data.meta.artist }}</span>
# 				<# } #>
# 			<# } #>
# 		</a>
# 		<# if ( data.meta.length_formatted ) { #>
# 		<div class="wp-playlist-item-length">{{ data.meta.length_formatted }}</div>
# 		<# } #>
# 	</div>
# </script>
# <!--[if IE 7]><style>
# .wpv-pagination { *zoom: 1; }
# </style><![endif]-->
# <script type='text/javascript' src='https://editorial.rottentomatoes.com/wp-content/themes/RottenTomatoes/js/bootstrap.js?ver=1.0'></script>
# <script type='text/javascript' src='https://editorial.rottentomatoes.com/wp-includes/js/jquery/ui/core.min.js?ver=1.11.4'></script>
# <script type='text/javascript' src='https://editorial.rottentomatoes.com/wp-includes/js/jquery/ui/datepicker.min.js?ver=1.11.4'></script>
# <script type='text/javascript'>
# jQuery(document).ready(function(jQuery){jQuery.datepicker.setDefaults({"closeText":"Close","currentText":"Today","monthNames":["January","February","March","April","May","June","July","August","September","October","November","December"],"monthNamesShort":["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"],"nextText":"Next","prevText":"Previous","dayNames":["Sunday","Monday","Tuesday","Wednesday","Thursday","Friday","Saturday"],"dayNamesShort":["Sun","Mon","Tue","Wed","Thu","Fri","Sat"],"dayNamesMin":["S","M","T","W","T","F","S"],"dateFormat":"MM d, yy","firstDay":1,"isRTL":false});});
# </script>
# <script type='text/javascript'>
# /* <![CDATA[ */
# var mejsL10n = {"language":"en-US","strings":{"Close":"Close","Fullscreen":"Fullscreen","Turn off Fullscreen":"Turn off Fullscreen","Go Fullscreen":"Go Fullscreen","Download File":"Download File","Download Video":"Download Video","Play":"Play","Pause":"Pause","Captions\/Subtitles":"Captions\/Subtitles","None":"None","Time Slider":"Time Slider","Skip back %1 seconds":"Skip back %1 seconds","Video Player":"Video Player","Audio Player":"Audio Player","Volume Slider":"Volume Slider","Mute Toggle":"Mute Toggle","Unmute":"Unmute","Mute":"Mute","Use Up\/Down Arrow keys to increase or decrease volume.":"Use Up\/Down Arrow keys to increase or decrease volume.","Use Left\/Right Arrow keys to advance one second, Up\/Down arrows to advance ten seconds.":"Use Left\/Right Arrow keys to advance one second, Up\/Down arrows to advance ten seconds."}};
# var _wpmejsSettings = {"pluginPath":"\/wp-includes\/js\/mediaelement\/"};
# var mejsL10n = {"language":"en-US","strings":{"Close":"Close","Fullscreen":"Fullscreen","Turn off Fullscreen":"Turn off Fullscreen","Go Fullscreen":"Go Fullscreen","Download File":"Download File","Download Video":"Download Video","Play":"Play","Pause":"Pause","Captions\/Subtitles":"Captions\/Subtitles","None":"None","Time Slider":"Time Slider","Skip back %1 seconds":"Skip back %1 seconds","Video Player":"Video Player","Audio Player":"Audio Player","Volume Slider":"Volume Slider","Mute Toggle":"Mute Toggle","Unmute":"Unmute","Mute":"Mute","Use Up\/Down Arrow keys to increase or decrease volume.":"Use Up\/Down Arrow keys to increase or decrease volume.","Use Left\/Right Arrow keys to advance one second, Up\/Down arrows to advance ten seconds.":"Use Left\/Right Arrow keys to advance one second, Up\/Down arrows to advance ten seconds."}};
# var _wpmejsSettings = {"pluginPath":"\/wp-includes\/js\/mediaelement\/"};
# /* ]]> */
# </script>
# <script type='text/javascript' src='https://editorial.rottentomatoes.com/wp-includes/js/mediaelement/mediaelement-and-player.min.js?ver=2.22.0'></script>
# <script type='text/javascript' src='https://editorial.rottentomatoes.com/wp-includes/js/mediaelement/wp-mediaelement.min.js?ver=4.7.3'></script>
# <script type='text/javascript' src='https://editorial.rottentomatoes.com/wp-includes/js/underscore.min.js?ver=1.8.3'></script>
# <script type='text/javascript'>
# /* <![CDATA[ */
# var _wpUtilSettings = {"ajax":{"url":"\/wp-admin\/admin-ajax.php"}};
# var _wpUtilSettings = {"ajax":{"url":"\/wp-admin\/admin-ajax.php"}};
# /* ]]> */
# </script>
# <script type='text/javascript' src='https://editorial.rottentomatoes.com/wp-includes/js/wp-util.min.js?ver=4.7.3'></script>
# <script type='text/javascript' src='https://editorial.rottentomatoes.com/wp-includes/js/backbone.min.js?ver=1.2.3'></script>
# <script type='text/javascript' src='https://editorial.rottentomatoes.com/wp-includes/js/mediaelement/wp-playlist.min.js?ver=4.7.3'></script>
# <script type='text/javascript'>
# /* <![CDATA[ */
# var wpv_pagination_local = {"front_ajaxurl":"https:\/\/editorial.rottentomatoes.com\/wp-admin\/admin-ajax.php","calendar_image":"https:\/\/editorial.rottentomatoes.com\/wp-content\/plugins\/wp-views\/embedded\/res\/img\/calendar.gif","calendar_text":"Select date","datepicker_min_date":null,"datepicker_max_date":null,"resize_debounce_tolerance":"100","datepicker_style_url":"https:\/\/editorial.rottentomatoes.com\/wp-content\/plugins\/wp-views\/embedded\/toolset\/toolset-common\/toolset-forms\/css\/wpt-jquery-ui\/jquery-ui-1.11.4.custom.css"};
# /* ]]> */
# </script>
# <script type='text/javascript' src='https://editorial.rottentomatoes.com/wp-content/plugins/wp-views/embedded/res/js/wpv-pagination-embedded.js?ver=2.3.1'></script>
# <script type='text/javascript' src='https://editorial.rottentomatoes.com/wp-includes/js/wp-embed.min.js?ver=4.7.3'></script>
# <script type='text/javascript'>
# /* <![CDATA[ */
# var embedVars = {"disqusConfig":{"platform":"wordpress@4.7.3","language":""},"disqusIdentifier":"172375 https:\/\/editorialadmin.rottentomatoes.com\/?post_type=guide&p=172375","disqusShortname":"rottentomatoes","disqusTitle":"The 100 Best Black Movies of the 21st Century \u2013 The Greatest New African American Films","disqusUrl":"https:\/\/editorial.rottentomatoes.com\/guide\/best-black-movies-21st-century\/","options":{"manualSync":"1"},"postId":"172375"};
# /* ]]> */
# </script>
# <script type='text/javascript' src='https://editorial.rottentomatoes.com/wp-content/plugins/disqus-comment-system/media/js/disqus.js?ver=4.7.3'></script>
# <script type='text/javascript'>
# /* <![CDATA[ */
# var countVars = {"disqusShortname":"rottentomatoes"};
# /* ]]> */
# </script>
# <script type='text/javascript' src='https://editorial.rottentomatoes.com/wp-content/plugins/disqus-comment-system/media/js/count.js?ver=4.7.3'></script>
#
#     <!-- BEGIN: wpflow ga events array -->
#     <script>
#
#                 jQuery(document).ready(function() {
#                     scroll_events.bind_events( {
#                         universal: 1,
#                         scroll_elements: [],
#                         click_elements: [{'select':'.ga_imdb','category':'Outbound Editorial Click','action':'click','label':'IMDb Outbound','bounce':'false'},{'select':'.ga_boxofficemojo','category':'Outbound Editorial Click','action':'click','label':'Box Office Mojo Outbound','bounce':'false'},{'select':'.ga_collider','category':'Outbound Editorial Click','action':'click','label':'Collider Outbound','bounce':'false'},{'select':'.ga_deadline','category':'Outbound Editorial Click','action':'click','label':'Deadline Outbound','bounce':'false'},{'select':'.ga_hollywoodreporter','category':'Outbound Editorial Click','action':'click','label':'Hollywood Reporter Outbound','bounce':'false'},{'select':'.ga_variety','category':'Outbound Editorial Click','action':'click','label':'Variety Outbound','bounce':'false'},{'select':'.ga_thewrap','category':'Outbound Editorial Click','action':'click','label':'The Wrap Outbound','bounce':'false'},{'select':'.ga_wikipedia','category':'Outbound Editorial Click','action':'click','label':'Wikipedia Outbound','bounce':'false'},{'select':'.ga_amazon','category':'Outbound Editorial Click','action':'click','label':'Amazon Outbound','bounce':'false'},{'select':'.ga_fandangonow','category':'Outbound Editorial Click','action':'click','label':'FandangoNOW Outbound','bounce':'false'},{'select':'.ga_google','category':'Outbound Editorial Click','action':'click','label':'Google Outbound','bounce':'false'},{'select':'.ga_apple','category':'Outbound Editorial Click','action':'click','label':'Apple Outbound','bounce':'false'},{'select':'.ga_microsoft','category':'Outbound Editorial Click','action':'click','label':'Microsoft Outbound','bounce':'false'},{'select':'.ga_netflix','category':'Outbound Editorial Click','action':'click','label':'Netflix Outbound','bounce':'false'},{'select':'.ga_playstation','category':'Outbound Editorial Click','action':'click','label':'Playstation Outbound','bounce':'false'},{'select':'.ga_vudu','category':'Outbound Editorial Click','action':'click','label':'Vudu Outbound','bounce':'false'},{'select':'.ga_marvel','category':'Outbound Editorial Click','action':'click','label':'Marvel Outbound','bounce':'false'},{'select':'.ga_dccomics','category':'Outbound Editorial Click','action':'click','label':'DC Comics Outbound','bounce':'false'}],
#                     });
#                 });
#
#     </script>
#     <!-- END: wpflow ga events array -->
# <script src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.1.14/require.js" data-main="https://editorial.rottentomatoes.com/wp-content/themes/RottenTomatoes/js/rtmain.js"></script>
#
# <script>
#     function endsWith(str, suffix) {
#       return str.indexOf(suffix, str.length - suffix.length) !== -1;
#     }
#
#     //--Ad Unit Loaded (called for each ad loaded)
#     var mps=mps||{}; mps._queue=mps._queue||{}; mps._queue.adload=mps._queue.adload||[];
#     mps._queue.adload.push(function(eo) {
#       window.console && console.log('**** AD LOADED: '+eo._mps.adslot);
#       if (!eo.isEmpty) {
#           console.log('MPS Slot Rendered: ' + eo.slot.getAdUnitPath() + " - " + eo.size + ' Creative Id: ' + eo.creativeId + ' Line Item Id: ' + eo.lineItemId);
#           if (eo._mps._slot == "topbanner") {
#               var leaderboardHeight = eo.size[1];
#               if (leaderboardHeight > 50){
#                    jQuery("#top_leaderboard_wrapper").animate({height:(leaderboardHeight+10)},1000);
#                     if (jQuery("#imageViewerModal").length > 0) {
#                       jQuery(".modalDialog").css("top", leaderboardHeight+10);
#                     }
#               }
#           }
#
#           if (eo._mps._slot == "trendinggraphic") {
#             //Hide Trending bar social section
#             jQuery("#trending_bar_social").hide();
#             //Removing padding for trending bar ad
#             jQuery(".trendingBar>.trendingEl").css("padding","0px");
#             jQuery("#trending_bar_ad").show();
#           }
#       }
#     });
# </script>
#
# <script type='text/javascript'>
#   var _sf_async_config = _sf_async_config || {};
#   /** CONFIGURATION START **/
#   _sf_async_config.sections ="guide";
#   _sf_async_config.authors = "rt-staff";
#
#   /** CONFIGURATION END **/
#   (function() {
#       function loadChartbeat() {
#           window._sf_endpt = (new Date()).getTime();
#           var e = document.createElement('script');
#           e.setAttribute('language', 'javascript');
#           e.setAttribute('type', 'text/javascript');
#
#           e.setAttribute('src', '//static.chartbeat.com/js/chartbeat_video.js');
#           document.body.appendChild(e);
#       }
#       var oldonload = window.onload;
#       window.onload = (typeof window.onload != 'function') ?
#           loadChartbeat : function() {
#               oldonload();
#               loadChartbeat();
#           };
#
#       })();
# </script>
#
# <script>mps.writeFooter && mps.writeFooter();</script>
# <script type="text/javascript">_satellite.pageBottom();</script>
#
#
#         <script>
#             jQuery(document).ready(function() {
#                 jQuery('[data-toggle="tooltip"]').tooltip();
#             });
#         </script>
#     </body>
# </html>
#
# <!-- Performance optimized by W3 Total Cache. Learn more: https://www.w3-edge.com/products/
#
# Database Caching 74/122 queries in 0.294 seconds using disk
#
#  Served from: rt-editorial-prod.aws.prod.flixster.com @ 2020-06-13 12:15:35 by W3 Total Cache -->

# %%
soup = BeautifulSoup(response.content, 'html.parser')

# %%
results = soup.find_all("h2")
results
# Out:
# [<h2><a href="https://www.rottentomatoes.com/m/keanu_2016/">Keanu</a> <span class="subtle start-year">(2016)</span> </h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/drumline/">Drumline</a> <span class="subtle start-year">(2002)</span> </h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/fast_color/">Fast Color</a> <span class="subtle start-year">(2019)</span> </h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/black_dynamite/">Black Dynamite</a> <span class="subtle start-year">(2009)</span> </h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/ghost_dog_the_way_of_the_samurai/">Ghost Dog - The Way of the Samurai</a> <span class="subtle start-year">(2000)</span> </h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/dreamgirls/">Dreamgirls</a> <span class="subtle start-year">(2006)</span> </h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/get_on_up/">Get On Up</a> <span class="subtle start-year">(2014)</span> </h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/1097991-george_washington/">George Washington</a> <span class="subtle start-year">(2000)</span> </h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/marshall/">Marshall</a> <span class="subtle start-year">(2017)</span> </h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/ray/">Ray</a> <span class="subtle start-year">(2004)</span> </h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/love_and_basketball/">Love and Basketball</a> <span class="subtle start-year">(2000)</span> </h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/barbershop/">Barbershop</a> <span class="subtle start-year">(2002)</span> </h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/rize/">Rize</a> <span class="subtle start-year">(2005)</span> </h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/beyond_the_lights/">Beyond the Lights</a> <span class="subtle start-year">(2014)</span> </h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/hustle_and_flow/">Hustle &amp; Flow</a> <span class="subtle start-year">(2005)</span> </h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/42_2013/">42</a> <span class="subtle start-year">(2013)</span> </h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/chi_raq/">Chi-Raq</a> <span class="subtle start-year">(2015)</span> </h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/american_gangster/">American Gangster</a> <span class="subtle start-year">(2007)</span> </h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/the_gospel_according_to_andre/">The Gospel According to André</a> <span class="subtle start-year">(2018)</span> </h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/monsters_and_men/">Monsters and Men</a> <span class="subtle start-year">(2018)</span> </h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/monsters_ball/">Monster's Ball</a> <span class="subtle start-year">(2002)</span> </h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/middle_of_nowhere/">Middle of Nowhere</a> <span class="subtle start-year">(2012)</span> </h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/bad_boys_for_life/">Bad Boys for Life</a> <span class="subtle start-year">(2020)</span> </h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/akeelah_and_the_bee/">Akeelah and the Bee</a> <span class="subtle start-year">(2006)</span> </h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/the-heart-of-the-game/">The Heart of the Game</a> <span class="subtle start-year">(2005)</span> </h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/what_happened_miss_simone_2015/">What Happened, Miss Simone?</a> <span class="subtle start-year">(2015)</span> </h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/queen_and_slim/">Queen &amp; Slim</a> <span class="subtle start-year">(2019)</span> </h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/beats_rhymes_and_life_the_travels_of_a_tribe_called_quest/">Beats Rhymes &amp; Life: The Travels of a Tribe Called Quest</a> <span class="subtle start-year">(2011)</span> </h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/1196003-princess_and_the_frog/">The Princess and the Frog</a> <span class="subtle start-year">(2009)</span> </h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/presenting_princess_shaw/">Presenting Princess Shaw</a> <span class="subtle start-year">(2016)</span> </h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/our_song/">Our Song</a> <span class="subtle start-year">(2001)</span> </h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/burning_cane/">Burning Cane</a> <span class="subtle start-year">(2019)</span> </h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/miss_sharon_jones/">Miss Sharon Jones!</a> <span class="subtle start-year">(2016)</span> </h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/madelines_madeline/">Madeline's Madeline</a> <span class="subtle start-year">(2018)</span> </h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/god_grew_tired_of_us/">God Grew Tired Of Us</a> <span class="subtle start-year">(2007)</span> </h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/waves_2019/">Waves</a> <span class="subtle start-year">(2019)</span> </h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/the_black_power_mix_tape_1967_1975/">The Black Power Mixtape 1967-1975</a> <span class="subtle start-year">(2011)</span> </h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/barbershop_the_next_cut_2016/">Barbershop: The Next Cut</a> <span class="subtle start-year">(2016)</span> </h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/inside_man/">Inside Man</a> <span class="subtle start-year">(2006)</span> </h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/top_five/">Top Five</a> <span class="subtle start-year">(2014)</span> </h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/standing_in_the_shadows_of_motown/">Standing in the Shadows of Motown</a> <span class="subtle start-year">(2002)</span> </h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/selah_and_the_spades/">Selah and the Spades</a> <span class="subtle start-year">(2020)</span> </h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/the_black_panthers_vanguard_of_the_revolution_2015/">The Black Panthers: Vanguard Of The Revolution</a> <span class="subtle start-year">(2015)</span> </h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/baadasssss/">Baadasssss!</a> <span class="subtle start-year">(2003)</span> </h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/the_central_park_five_2012/">The Central Park Five</a> <span class="subtle start-year">(2012)</span> </h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/beasts_of_the_southern_wild/">Beasts of the Southern Wild</a> <span class="subtle start-year">(2012)</span> </h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/whitney_2018/">Whitney</a> <span class="subtle start-year">(2018)</span> </h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/dope_2015/">Dope</a> <span class="subtle start-year">(2015)</span> </h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/miles_davis_birth_of_the_cool/">Miles Davis: Birth of the Cool</a> <span class="subtle start-year">(2019)</span> </h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/detroit_2017/">Detroit</a> <span class="subtle start-year">(2017)</span> </h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/premature_2020/">Premature</a> <span class="subtle start-year">(2020)</span> </h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/clemency_2019/">Clemency</a> <span class="subtle start-year">(2019)</span> </h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/dear_white_people/">Dear White People</a> <span class="subtle start-year">(2014)</span> </h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/block_party/">Dave Chappelle's Block Party</a> <span class="subtle start-year">(2006)</span> </h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/just_mercy/">Just Mercy</a> <span class="subtle start-year">(2020)</span> </h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/creed_ii/">Creed II</a> <span class="subtle start-year">(2018)</span> </h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/good_hair/">Good Hair</a> <span class="subtle start-year">(2009)</span> </h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/straight_outta_compton/">Straight Outta Compton</a> <span class="subtle start-year">(2015)</span> </h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/support_the_girls/">Support the Girls</a> <span class="subtle start-year">(2018)</span> </h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/it_comes_at_night/">It Comes At Night</a> <span class="subtle start-year">(2017)</span> </h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/luce/">Luce</a> <span class="subtle start-year">(2019)</span> </h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/django_unchained_2012/">Django Unchained</a> <span class="subtle start-year">(2012)</span> </h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/girls_trip/">Girls Trip</a> <span class="subtle start-year">(2017)</span> </h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/southside_with_you/">Southside With You</a> <span class="subtle start-year">(2016)</span> </h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/pariah_2011/">Pariah</a> <span class="subtle start-year">(2011)</span> </h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/precious/">Precious: Based on the Novel Push by Sapphire</a> <span class="subtle start-year">(2009)</span> </h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/keep_on_keepin_on/">Keep On Keepin' On</a> <span class="subtle start-year">(2014)</span> </h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/hale_county_this_morning_this_evening/">Hale County This Morning, This Evening</a> <span class="subtle start-year">(2018)</span> </h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/step_2017/">Step</a> <span class="subtle start-year">(2017)</span> </h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/13th/">13th</a> <span class="subtle start-year">(2016)</span> </h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/loving_2016/">Loving</a> <span class="subtle start-year">(2016)</span> </h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/toni_morrison_the_pieces_i_am/">Toni Morrison: The Pieces I Am</a> <span class="subtle start-year">(2019)</span> </h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/blindspotting/">Blindspotting</a> <span class="subtle start-year">(2018)</span> </h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/whose_streets/">Whose Streets?</a> <span class="subtle start-year">(2017)</span> </h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/strong_island/">Strong Island</a> <span class="subtle start-year">(2017)</span> </h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/night_comes_on/">Night Comes On</a> <span class="subtle start-year">(2018)</span> </h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/oj_made_in_america/">O.J.: Made in America</a> <span class="subtle start-year">(2016)</span> </h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/tangerine_2015/">Tangerine</a> <span class="subtle start-year">(2015)</span> </h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/the_last_black_man_in_san_francisco/">The Last Black Man in San Francisco</a> <span class="subtle start-year">(2019)</span> </h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/fruitvale_station/">Fruitvale Station</a> <span class="subtle start-year">(2013)</span> </h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/fences_2016/">Fences</a> <span class="subtle start-year">(2016)</span> </h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/20_feet_from_stardom/">20 Feet From Stardom</a> <span class="subtle start-year">(2013)</span> </h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/mudbound/">Mudbound</a> <span class="subtle start-year">(2017)</span> </h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/amazing_grace_2018/">Amazing Grace</a> <span class="subtle start-year">(2019)</span> </h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/sorry_to_bother_you_2018/">Sorry to Bother You</a> <span class="subtle start-year">(2018)</span> </h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/the_hate_u_give/">The Hate U Give</a> <span class="subtle start-year">(2018)</span> </h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/hidden_figures/">Hidden Figures</a> <span class="subtle start-year">(2017)</span> </h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/dolemite_is_my_name/">Dolemite Is My Name</a> <span class="subtle start-year">(2019)</span> </h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/creed_2015/">Creed</a> <span class="subtle start-year">(2015)</span> </h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/i_am_not_your_negro/">I Am Not Your Negro</a> <span class="subtle start-year">(2017)</span> </h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/widows_2018/">Widows</a> <span class="subtle start-year">(2018)</span> </h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/12_years_a_slave/">12 Years a Slave</a> <span class="subtle start-year">(2013)</span> </h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/if_beale_street_could_talk/">If Beale Street Could Talk</a> <span class="subtle start-year">(2019)</span> </h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/selma/">Selma</a> <span class="subtle start-year">(2014)</span> </h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/moonlight_2016/">Moonlight</a> <span class="subtle start-year">(2016)</span> </h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/spider_man_into_the_spider_verse/">Spider-Man: Into the Spider-Verse</a> <span class="subtle start-year">(2018)</span> </h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/get_out/">Get Out</a> <span class="subtle start-year">(2017)</span> </h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/blackkklansman/">BlacKkKlansman</a> <span class="subtle start-year">(2018)</span> </h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/us_2019/">Us</a> <span class="subtle start-year">(2019)</span> </h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/black_panther_2018/">Black Panther</a> <span class="subtle start-year">(2018)</span> </h2>,
#  <h2 class="panel-heading"><a href="https://editorial.rottentomatoes.com/more-related-content/?ref=172375&amp;relatedmovieid=1788,2132,10283,10414,10577,11030,11438,12784,13267,13368,14819,15861,17495,49248977,126518499,152552156,155655104,358047697,493864880,770671119,770679318,770682608,770800373,770802637,770803691,770873459,771205918,771228631,771234052,771245718,771266910,771267232,771267578,771305050,771305747,771307293,771316210,771324998,771325066,771359010,771371300,771372054,771377311,771377991,771383243,771387806,771388482,771401855,771412029,771412106,771412118,771412133,771413507,771418740,771419654,771419700,771428993,771429024,771436012,771439525,771440535,771441788,771442788,771445674,771446056,771446861,771450230,771454573,771466968,771467011,771467013,771467015,771468387,771472582,771484225,771484409,771488671,771489086,771489122,771489131,771489136,771489869,771490193,771490573,771491185,771491442,771491679,771492508,771492648,771493505,771493877,771496311,771498427,771501032,771501713,771501778,771503979,771504198,771506750,771511527,771512514" style="text-decoration:none; color:#1C1C1C;">Related News</a></h2>,
#  <h2 class="panel-heading"><a href="https://editorial.rottentomatoes.com/countdown/" style="text-decoration:none; color:#1C1C1C;">More Countdown</a></h2>,
#  <h2 class="panel-heading">Movie &amp; TV News</h2>,
#  <h2>Featured on RT</h2>,
#  <h2>Top Headlines</h2>,
#  <h2 class="panel-heading">Tag Cloud</h2>,
#  <h2>Follow Us</h2>]

# %%
movies = []

for result in results:
    title = result.text
    movies.append(title)
movies = movies[0:100]

#Replacing Fast Color 2019 because IMDb has it as released in 2018
movies[2] = movies[2].replace("(2019)", "(2018)")
movies
# Out:
# ['Keanu (2016) ',
#  'Drumline (2002) ',
#  'Fast Color (2018) ',
#  'Black Dynamite (2009) ',
#  'Ghost Dog - The Way of the Samurai (2000) ',
#  'Dreamgirls (2006) ',
#  'Get On Up (2014) ',
#  'George Washington (2000) ',
#  'Marshall (2017) ',
#  'Ray (2004) ',
#  'Love and Basketball (2000) ',
#  'Barbershop (2002) ',
#  'Rize (2005) ',
#  'Beyond the Lights (2014) ',
#  'Hustle & Flow (2005) ',
#  '42 (2013) ',
#  'Chi-Raq (2015) ',
#  'American Gangster (2007) ',
#  'The Gospel According to André (2018) ',
#  'Monsters and Men (2018) ',
#  "Monster's Ball (2002) ",
#  'Middle of Nowhere (2012) ',
#  'Bad Boys for Life (2020) ',
#  'Akeelah and the Bee (2006) ',
#  'The Heart of the Game (2005) ',
#  'What Happened, Miss Simone? (2015) ',
#  'Queen & Slim (2019) ',
#  'Beats Rhymes & Life: The Travels of a Tribe Called Quest (2011) ',
#  'The Princess and the Frog (2009) ',
#  'Presenting Princess Shaw (2016) ',
#  'Our Song (2001) ',
#  'Burning Cane (2019) ',
#  'Miss Sharon Jones! (2016) ',
#  "Madeline's Madeline (2018) ",
#  'God Grew Tired Of Us (2007) ',
#  'Waves (2019) ',
#  'The Black Power Mixtape 1967-1975 (2011) ',
#  'Barbershop: The Next Cut (2016) ',
#  'Inside Man (2006) ',
#  'Top Five (2014) ',
#  'Standing in the Shadows of Motown (2002) ',
#  'Selah and the Spades (2020) ',
#  'The Black Panthers: Vanguard Of The Revolution (2015) ',
#  'Baadasssss! (2003) ',
#  'The Central Park Five (2012) ',
#  'Beasts of the Southern Wild (2012) ',
#  'Whitney (2018) ',
#  'Dope (2015) ',
#  'Miles Davis: Birth of the Cool (2019) ',
#  'Detroit (2017) ',
#  'Premature (2020) ',
#  'Clemency (2019) ',
#  'Dear White People (2014) ',
#  "Dave Chappelle's Block Party (2006) ",
#  'Just Mercy (2020) ',
#  'Creed II (2018) ',
#  'Good Hair (2009) ',
#  'Straight Outta Compton (2015) ',
#  'Support the Girls (2018) ',
#  'It Comes At Night (2017) ',
#  'Luce (2019) ',
#  'Django Unchained (2012) ',
#  'Girls Trip (2017) ',
#  'Southside With You (2016) ',
#  'Pariah (2011) ',
#  'Precious: Based on the Novel Push by Sapphire (2009) ',
#  "Keep On Keepin' On (2014) ",
#  'Hale County This Morning, This Evening (2018) ',
#  'Step (2017) ',
#  '13th (2016) ',
#  'Loving (2016) ',
#  'Toni Morrison: The Pieces I Am (2019) ',
#  'Blindspotting (2018) ',
#  'Whose Streets? (2017) ',
#  'Strong Island (2017) ',
#  'Night Comes On (2018) ',
#  'O.J.: Made in America (2016) ',
#  'Tangerine (2015) ',
#  'The Last Black Man in San Francisco (2019) ',
#  'Fruitvale Station (2013) ',
#  'Fences (2016) ',
#  '20 Feet From Stardom (2013) ',
#  'Mudbound (2017) ',
#  'Amazing Grace (2019) ',
#  'Sorry to Bother You (2018) ',
#  'The Hate U Give (2018) ',
#  'Hidden Figures (2017) ',
#  'Dolemite Is My Name (2019) ',
#  'Creed (2015) ',
#  'I Am Not Your Negro (2017) ',
#  'Widows (2018) ',
#  '12 Years a Slave (2013) ',
#  'If Beale Street Could Talk (2019) ',
#  'Selma (2014) ',
#  'Moonlight (2016) ',
#  'Spider-Man: Into the Spider-Verse (2018) ',
#  'Get Out (2017) ',
#  'BlacKkKlansman (2018) ',
#  'Us (2019) ',
#  'Black Panther (2018) ']

# %%
#Import pandas and IMDb libraries
import pandas as pd
from imdb import IMDb

# %%
#create instance of IMDb class
ia = IMDb()

# %%
#Loop through Rotten Tomatoes 100 Best Black Movies of the 21st Century to get their movie name on IMDb
movie_names=[]
for movie in movies:
    movie_results = ia.search_movie(movie)
    movie_names.append(movie_results[0]["title"])

# %%
len(movie_names)
# Out:
# 100

# %%
#Using their IMDb name, grab these movies ids, ratings, and cast names
movie_ids = []


for movie_name in movie_names:
    movie_ids.append(movie_name.getID())

# %%
len(movie_ids)
# Out:
# 100

# %%
movie_ratings=[]
cast_0_names = []
cast_1_names = []

for movie_id in movie_ids:
    try:
        rating = ia.get_movie(movie_id).get("rating")
        movie_ratings.append(rating)
    except:
        movie_ratings.append(None)
    try:
        cast_0_name = ia.get_movie(movie_id).get("cast")[0]["name"]
        cast_1_name = ia.get_movie(movie_id).get("cast")[1]["name"]
        cast_0_names.append(cast_0_name)
        cast_1_names.append(cast_1_name)
    except:
        cast_0_names.append(None)
        cast_1_names.append(None)

# %%
len(movie_ratings)
# Out:
# 100

# %%
len(cast_0_names)
# Out:
# 100

# %%
len(cast_1_names)
# Out:
# 100

# %%
#Using cast name, grab the cast member's ID
cast_0_ids = []
cast_1_ids = []

for movie_id in movie_ids:
    try:
        cast_0_ids.append(ia.get_movie(movie_id).get("cast")[0].getID())
    except:
        cast_0_ids.append(None)

for movie_id in movie_ids:
    try:
        cast_1_ids.append(ia.get_movie(movie_id).get("cast")[1].getID())
    except:
        cast_1_ids.append(None)

# %%
len(cast_0_ids)
# Out:
# 100

# %%
len(cast_1_ids)
# Out:
# 100

# %%
plots=[]

for movie_id in movie_ids:
    try:
        plots.append(ia.get_movie(movie_id).get('plot')[0])
    except:
        plots.append(None)

# %%
len(plots)
# Out:
# 'When the adorable kitten of an L.A. crime kingpin unexpectedly enters the life of two cousins, they will have to go through tough gangs, pitiless hit-men, and ruthless drug dealers who all claim him, to get him back. How hard can it be?::Nick Riganas'

# %%
movie_info = pd.DataFrame({"movie id": movie_ids, "movie names": movie_names, "plot": plots, 
                           "IMDb Rating": movie_ratings, 
                           "main cast member id": cast_0_ids, "main cast member name": cast_0_names, 
                           "other cast member id": cast_1_ids, "other cast member name": cast_1_names})
movie_info
# Out:
#    movie id                        movie names  \
# 0   4139124                              Keanu
# 1   0303933                           Drumline
# 2   6418778                        Fast Colour
# 3   1190536                     Black Dynamite
# 4   0165798  Ghost Dog: The Way of the Samurai
# ..      ...                                ...
# 95  4633694  Spider-Man: Into the Spider-Verse
# 96  5052448                            Get Out
# 97  7349662                     BlacKkKlansman
# 98  6857112                                 Us
# 99  1825683                      Black Panther
#
#                                                  plot  IMDb Rating  \
# 0   When the adorable kitten of an L.A. crime king...          6.2
# 1   A band director recruits a Harlem street drumm...          5.8
# 2   After years in hiding, a woman is forced to go...          6.0
# 3   Black Dynamite is the greatest African-America...          7.4
# 4   An African-American Mafia hit man who models h...          7.5
# ..                                                ...          ...
# 95  Teen Miles Morales becomes Spider-Man of his r...          8.4
# 96  A young African-American visits his white girl...          7.7
# 97  Ron Stallworth, an African American police off...          7.5
# 98  A family's serene beach vacation turns to chao...          6.9
# 99  T'Challa, heir to the hidden but advanced king...          7.3
#
#    main cast member id main cast member name other cast member id  \
# 0              1443502          Jordan Peele              1221047
# 1              0134244           Nick Cannon              0757855
# 2              1813221       Gugu Mbatha-Raw              0000657
# 3              0032399     Phyllis Applegate              0044762
# 4              0001845       Forest Whitaker              0868110
# ..                 ...                   ...                  ...
# 95             4271336         Shameik Moore              2159926
# 96             2257207        Daniel Kaluuya              4129745
# 97             0000285          Alec Baldwin              0913475
# 98             2143282        Lupita Nyong'o              6328300
# 99             1569276      Chadwick Boseman              0430107
#
#    other cast member name
# 0      Keegan-Michael Key
# 1             Zoe Saldana
# 2        David Strathairn
# 3          Obba Babatundé
# 4             John Tormey
# ..                    ...
# 95           Jake Johnson
# 96       Allison Williams
# 97  John David Washington
# 98           Winston Duke
# 99      Michael B. Jordan
#
# [100 rows x 8 columns]

# %%
movie_info.to_csv("movies.csv",index=False)

# %%
cast_ids = list(set().union(cast_0_ids, cast_1_ids))

# %%
cast_names = []

for cast_id in cast_ids:
    try:
        cast_names.append(ia.get_person(cast_id)["name"])
    except:
        cast_names.append(None)

# %%
latest_role = []

for cast_id in cast_ids:
    try:
        latest_role.append(ia.get_person(cast_id)["filmography"][0]["actor"][0]["title"])
    except:
        try:
            latest_role.append(ia.get_person(cast_id)["filmography"][0]["actress"][0]["title"])
        except:
            latest_role.append(None)

# %%
cast_df = pd.DataFrame({"cast id": cast_ids, "cast name": cast_names, "latest role": latest_role})
cast_df
# Out:
#      cast id              cast name           latest role
# 0    0913475  John David Washington   Born to Be Murdered
# 1    0362426       Bethann Hardison                  None
# 2    2981935         Blake Anderson                  Woke
# 3    2993749      Michael Brown Sr.           Unborn Sins
# 4    0461498                Beyoncé                  None
# ..       ...                    ...                   ...
# 162  1165044         Omari Hardwick       Die Enormous ()
# 163  0004937             Jamie Foxx              Spawn ()
# 164  2022922      Darnellia Russell                  None
# 165  0654110             Clive Owen      Lisey's Story ()
# 166  0001845        Forest Whitaker  A Fall from Grace ()
#
# [167 rows x 3 columns]

# %%
cast_df.to_csv("cast.csv",index=False)
